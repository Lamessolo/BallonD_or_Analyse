# %% [markdown]
# ## Ajouter le pays du club dans lequel joue le nominé dans notre Tableau

# %%
# Etapes 

# Ouvrir le fichier csv necessaire 

# Ajouter une colonne au tableau de joueurs appeler "country" 

# Alimenter cette colonne avec une valeur par default (neant)

# Creer des tableaux par pays des differentes équipes 

# En fonction du club du joueur remplir la colonne country 

# mettre en place le meme proceder pour la confédération et la selection

# %%
#Ouvrir et llire le csv necessaire
import pandas as pd

tab_players_1989 = pd.read_csv("players_90_99/tab_players_1989.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1989.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
    tab_players_1989.insert(loc=4, column='Country', value='neant')

# Modifier une cellule spécifique
tab_players_1989.at[0,'Club'] = 'Milan AC'


# Creer des listes par pays des differentes équipes
france_liste = ["Paris","Nice","Marseille"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid"]
italie_liste = ["Juventus FC","Sampdoria","Milan AC","Inter Milan"]
allemagne_liste=["Cologne","Werder Bremen", "Borussia Dortmund"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Tottenham Hotspur"]
belguim_liste=["Mechelen"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1989['Club'].isin(france_liste)
spain_club = tab_players_1989['Club'].isin(espagne_liste)
italie_Club = tab_players_1989['Club'].isin(italie_liste)
allemagne_Club = tab_players_1989['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1989['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1989['Club'].isin(belguim_liste)
russie_Club = tab_players_1989['Club'].isin(russie_liste)
roumania_Club = tab_players_1989['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1989['Club'].isin(ukraine_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1989.loc[french_club, 'Country'] = 'France'
tab_players_1989.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1989.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1989.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1989.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1989.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1989.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1989.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1989.loc[roumania_Club, 'Country'] = 'Roumanie'

 # ecrire un dataframe dans un fichier
tab_players_1989.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1989.csv', sep = ',',header=True, index=False)

tab_players_1989
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                     Nom               Club     Country  \
# 0           377     1        Marco van Basten           Milan AC      Italie
# 1           378     2           Franco Baresi           Milan AC      Italie
# 2           379     3          Frank Rijkaard           Milan AC      Italie
# 3           380     4         Lothar Matthaus        Inter Milan      Italie
# 4           381     5           Peter Shilton       Derby County  Angleterre
# 5           382     6        Dragan Stojkovic  Red Star Belgrade      Russie
# 6           383     7             Ruud Gullit           Milan AC      Italie
# 7           384     8           Gheorghe Hagi   Steauat Bucarest    Roumanie
# 8           385     8        Jurgen Klinsmann        Inter Milan      Italie
# 9           386    10       Jean-Pierre Papin          Marseille      France
# 10          387    10      Michel Preud'homme           Mechelen    Belgique
# ...

# %%
#Ouvrir et llire le csv necessaire
import pandas as pd
tab_players_1990 = pd.read_csv("players_90_99/tab_players_1990.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1990.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
    # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1990.insert(loc=4, column='Country', value='neant')

# Modifier une cellule spécifique
tab_players_1990.at[7,'Club'] = 'Fiorentina'
# Modifier une cellule spécifique
tab_players_1990.at[11,'Club'] = 'Real Madrid'
tab_players_1990.at[16,'Club'] = 'Red Star Belgrade'


# Creer des listes par pays des differentes équipes
france_liste = ["Paris","Nice","Marseille","Auxerre"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone"]
italie_liste = ["Juventus FC","Sampdoria","Milan AC","Inter Milan","Fiorentina","Roma"]
allemagne_liste=["Cologne","Werder Bremen", "Borussia Dortmund","VfB Stuttgart"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Tottenham Hotspur","Aston Villa","Nottingham Forest"]
belguim_liste=["Mechelen"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1990['Club'].isin(france_liste)
spain_club = tab_players_1990['Club'].isin(espagne_liste)
italie_Club = tab_players_1990['Club'].isin(italie_liste)
allemagne_Club = tab_players_1990['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1990['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1990['Club'].isin(belguim_liste)
russie_Club = tab_players_1990['Club'].isin(russie_liste)
roumania_Club = tab_players_1990['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1990['Club'].isin(ukraine_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1990.loc[french_club, 'Country'] = 'France'
tab_players_1990.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1990.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1990.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1990.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1990.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1990.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1990.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1990.loc[roumania_Club, 'Country'] = 'Roumanie'

 # ecrire un dataframe dans un fichier
tab_players_1990.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1990.csv', sep = ',',header=True, index=False)

tab_players_1990
# Out:
# La colonne 'Country' n'existe pas dans le DataFrame.
#     Primary_Key  Rank                    Nom               Club     Country  \
# 0             1     1        Lothar Matthaus        Inter Milan      Italie
# 1             2     2    Salvatore Schillaci        Juventus FC      Italie
# 2             3     3         Andreas Brehme        Inter Milan      Italie
# 3             4     4         Paul Gascoigne  Tottenham Hotspur  Angleterre
# 4             5     5          Franco Baresi           Milan AC      Italie
# 5             6     6             Enzo Scifo            Auxerre      France
# 6             7     6       Jurgen Klinsmann        Inter Milan      Italie
# 7             8     8         Roberto Baggio         Fiorentina      Italie
# 8             9     9         Frank Rijkaard           Milan AC      Italie
# 9            10    10         Guido Buchwald      VfB Stuttgart   Allemagne
# 10           11    11      Jean-Pierre Papin          Marseille      France
# ...

# %%
#Ouvrir et llire le csv necessaire
import pandas as pd
tab_players_1991 = pd.read_csv("players_90_99/tab_players_1991.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1991.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
    # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1991.insert(loc=4, column='Country', value='neant')

# Modifier une cellule spécifique
#tab_players_1991.at[7,'Club'] = 'Fiorentina'
# Modifier une cellule spécifique
tab_players_1991.at[16,'Club'] = 'Derby County'
tab_players_1991.at[4,'Club'] = 'Red Star Belgrade'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris","Nice","Marseille","Auxerre"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone"]
italie_liste = ["Juventus FC","Sampdoria","Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple"]
allemagne_liste=["Cologne","Werder Bremen", "Borussia Dortmund","VfB Stuttgart","Bayern Munich"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"] 
greece_liste=["Panathinaikos"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1991['Club'].isin(france_liste)
spain_club = tab_players_1991['Club'].isin(espagne_liste)
italie_Club = tab_players_1991['Club'].isin(italie_liste)
allemagne_Club = tab_players_1991['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1991['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1991['Club'].isin(belguim_liste)
russie_Club = tab_players_1991['Club'].isin(russie_liste)
roumania_Club = tab_players_1991['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1991['Club'].isin(ukraine_liste)
greece_Club = tab_players_1991['Club'].isin(greece_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1991.loc[french_club, 'Country'] = 'France'
tab_players_1991.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1991.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1991.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1991.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1991.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1991.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1991.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1991.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1991.loc[greece_Club, 'Country'] = 'Grece'

 # ecrire un dataframe dans un fichier
tab_players_1991.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1991.csv', sep = ',',header=True, index=False)

tab_players_1991
# Out:
# La colonne 'Country' n'existe pas dans le DataFrame.
#     Primary_Key  Rank                    Nom       Selection     Country  \
# 0            24     1      Jean-Pierre Papin          France      France
# 1            25     2        Dejan Savicevic     Yougoslavie      Russie
# 2            26     2           Darko Pancev     Yougoslavie      Russie
# 3            27     2        Lothar Matthaus       Allemagne      Italie
# 4            28     5      Robert Prosinecki     Yougoslavie      Russie
# 5            29     6           Gary Lineker      Angleterre  Angleterre
# 6            30     7        Gianluca Vialli          Italie      Italie
# 7            31     8     Miodrag Belodedici        Roumanie      Russie
# 8            32     9            Mark Hughes  Pays de Galles  Angleterre
# 9            33    10           Chris Waddle      Angleterre      France
# 10           34    11        Michael Laudrup        Danemark     Espagne
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1992 = pd.read_csv("players_90_99/tab_players_1992.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1992.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1992.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1992.at[7,'Club'] = 'Fiorentina'
# Modifier une cellule spécifique
#tab_players_1992.at[16,'Club'] = 'Derby County'
#tab_players_1992.at[4,'Club'] = 'Red Star Belgrade'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris","Nice","Marseille","Auxerre"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone"]
italie_liste = ["Juventus FC","Sampdoria",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen", "Borussia Dortmund","VfB Stuttgart","Bayern Munich"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"]
greece_liste=["Panathinaikos"]
hollande_liste=["Ajax"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1992['Club'].isin(france_liste)
spain_club = tab_players_1992['Club'].isin(espagne_liste)
italie_Club = tab_players_1992['Club'].isin(italie_liste)
allemagne_Club = tab_players_1992['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1992['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1992['Club'].isin(belguim_liste)
russie_Club = tab_players_1992['Club'].isin(russie_liste)
roumania_Club = tab_players_1992['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1992['Club'].isin(ukraine_liste)
greece_Club = tab_players_1992['Club'].isin(greece_liste)
hollande_Club = tab_players_1992['Club'].isin(hollande_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1992.loc[french_club, 'Country'] = 'France'
tab_players_1992.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1992.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1992.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1992.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1992.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1992.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1992.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1992.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1992.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1992.loc[hollande_Club, 'Country'] = 'Pays-Bas'

 # ecrire un dataframe dans un fichier
tab_players_1992.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1992.csv', sep = ',',header=True, index=False)
tab_players_1992
# Out:
# La colonne 'Country' n'existe pas dans le DataFrame.
#     Primary_Key  Rank                 Nom               Club     Country  \
# 0            54     1    Marco van Basten           Milan AC      Italie
# 1            55     2    Hristo Stoichkov       FC Barcelone     Espagne
# 2            56     3     Dennis Bergkamp               Ajax    Pays-Bas
# 3            57     4      Thomas Hassler               Roma      Italie
# 4            58     5    Peter Schmeichel  Manchester United  Angleterre
# 5            59     6       Brian Laudrup         Fiorentina      Italie
# 6            60     7     Michael Laudrup       FC Barcelone     Espagne
# 7            61     8       Ronald Koeman       FC Barcelone     Espagne
# 8            62     9  Stephane Chapuisat  Borussia Dortmund   Allemagne
# 9            63    10      Frank Rijkaard           Milan AC      Italie
# 10           64    10          Enzo Scifo             Torino      Italie
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1993 = pd.read_csv("players_90_99/tab_players_1993.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1993.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1993.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1993.at[7,'Club'] = 'Fiorentina'
# Modifier une cellule spécifique
#tab_players_1993.at[16,'Club'] = 'Derby County'
#tab_players_1993.at[4,'Club'] = 'Red Star Belgrade'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris","Nice","Marseille","Auxerre","Monaco"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone"]
italie_liste = ["Juventus FC","Sampdoria",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen", 
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto"]
greece_liste=["Panathinaikos","AEK Athens"]
hollande_liste=["Ajax"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1993['Club'].isin(france_liste)
spain_club = tab_players_1993['Club'].isin(espagne_liste)
italie_Club = tab_players_1993['Club'].isin(italie_liste)
allemagne_Club = tab_players_1993['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1993['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1993['Club'].isin(belguim_liste)
russie_Club = tab_players_1993['Club'].isin(russie_liste)
roumania_Club = tab_players_1993['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1993['Club'].isin(ukraine_liste)
greece_Club = tab_players_1993['Club'].isin(greece_liste)
hollande_Club = tab_players_1993['Club'].isin(hollande_liste)
portugal_Club = tab_players_1993['Club'].isin(portugal_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1993.loc[french_club, 'Country'] = 'France'
tab_players_1993.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1993.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1993.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1993.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1993.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1993.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1993.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1993.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1993.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1993.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1993.loc[portugal_Club, 'Country'] = 'Portugal'

 # ecrire un dataframe dans un fichier
tab_players_1993.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1993.csv', sep = ',',header=True, index=False)
tab_players_1993
# Out:
# La colonne 'Country' n'existe pas dans le DataFrame.
#     Primary_Key  Rank                 Nom                      Club  \
# 0            75     1      Roberto Baggio               Juventus FC
# 1            76     2     Dennis Bergkamp               Inter Milan
# 2            77     3        Eric Cantona         Manchester United
# 3            78     4         Alen Boksic                     Lazio
# 4            79     5     Michael Laudrup              FC Barcelone
# 5            80     6       Franco Baresi                  Milan AC
# 6            81     7       Paolo Maldini                  Milan AC
# 7            82     8     Emil Kostadinov                     Porto
# 8            83     9  Stephane Chapuisat         Borussia Dortmund
# 9            84     9          Ryan Giggs         Manchester United
# 10           85    11      Andreas Moller               Juventus FC
# 11           86    12         Ruud Gullit                 Sampdoria
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1994 = pd.read_csv("players_90_99/tab_players_1994.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1994.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1994.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1994.at[7,'Club'] = 'Fiorentina'
# Modifier une cellule spécifique
#tab_players_1994.at[16,'Club'] = 'Derby County'
#tab_players_1994.at[4,'Club'] = 'Red Star Belgrade'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone"]
italie_liste = ["Juventus FC","Sampdoria",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Newcastle United",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens"]
hollande_liste=["Ajax"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1994['Club'].isin(france_liste)
spain_club = tab_players_1994['Club'].isin(espagne_liste)
italie_Club = tab_players_1994['Club'].isin(italie_liste)
allemagne_Club = tab_players_1994['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1994['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1994['Club'].isin(belguim_liste)
russie_Club = tab_players_1994['Club'].isin(russie_liste)
roumania_Club = tab_players_1994['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1994['Club'].isin(ukraine_liste)
greece_Club = tab_players_1994['Club'].isin(greece_liste)
hollande_Club = tab_players_1994['Club'].isin(hollande_liste)
portugal_Club = tab_players_1994['Club'].isin(portugal_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1994.loc[french_club, 'Country'] = 'France'
tab_players_1994.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1994.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1994.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1994.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1994.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1994.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1994.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1994.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1994.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1994.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1994.loc[portugal_Club, 'Country'] = 'Portugal'

 # ecrire un dataframe dans un fichier
tab_players_1994.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1994.csv', sep = ',',header=True, index=False)
tab_players_1994
# Out:
# La colonne 'Country' n'existe pas dans le DataFrame.
#     Primary_Key  Rank                 Nom    Selection     Country  \
# 0           105     1    Hristo Stoichkov     Bulgarie     Espagne
# 1           106     2      Roberto Baggio       Italie      Italie
# 2           107     3       Paolo Maldini       Italie      Italie
# 3           108     4       Gheorghe Hagi      Romania     Espagne
# 4           109     4        Tomas Brolin        Suede      Italie
# 5           110     6    Jurgen Klinsmann    Allemagne  Angleterre
# 6           111     7      Thomas Ravelli        Suede       neant
# 7           112     8       Jari Litmanen      Finland    Pays-Bas
# 8           113     9     Marcel Desailly       France      Italie
# 9           114     9     Dejan Savicevic  Yougoslavie      Italie
# 10          115    11       Franco Baresi       Italie      Italie
# 11          116    11  Michel Preud'homme     Belgique    Portugal
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1995 = pd.read_csv("players_90_99/tab_players_1995.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1995.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1995.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_1995.at[0,'Club'] = 'Paris Saint-Germain'
# Modifier une cellule spécifique
tab_players_1995.at[1,'Club'] = 'Tottenham Hotspur'
tab_players_1995.at[26,'Club'] = 'Real Zaragoza'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Newcastle United","Leeds United","Blackburn Rovers",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens"]
hollande_liste=["Ajax","PSV Eindhoven"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1995['Club'].isin(france_liste)
spain_club = tab_players_1995['Club'].isin(espagne_liste)
italie_Club = tab_players_1995['Club'].isin(italie_liste)
allemagne_Club = tab_players_1995['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1995['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1995['Club'].isin(belguim_liste)
russie_Club = tab_players_1995['Club'].isin(russie_liste)
roumania_Club = tab_players_1995['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1995['Club'].isin(ukraine_liste)
greece_Club = tab_players_1995['Club'].isin(greece_liste)
hollande_Club = tab_players_1995['Club'].isin(hollande_liste)
portugal_Club = tab_players_1995['Club'].isin(portugal_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1995.loc[french_club, 'Country'] = 'France'
tab_players_1995.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1995.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1995.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1995.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1995.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1995.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1995.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1995.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1995.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1995.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1995.loc[portugal_Club, 'Country'] = 'Portugal'

 # ecrire un dataframe dans un fichier
tab_players_1995.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1995.csv', sep = ',',header=True, index=False)
tab_players_1995
# Out:
# La colonne 'Country' n'existe pas dans le DataFrame.
#     Primary_Key  Rank                   Nom                  Club     Country  \
# 0           133     1           George Weah   Paris Saint-Germain      France
# 1           134     2      Jurgen Klinsmann     Tottenham Hotspur  Angleterre
# 2           135     3         Jari Litmanen                  Ajax    Pays-Bas
# 3           136     4  Alessandro Del Piero           Juventus FC      Italie
# 4           137     5      Patrick Kluivert                  Ajax    Pays-Bas
# 5           138     6       Gianfranco Zola                 Parma      Italie
# 6           139     7         Paolo Maldini              Milan AC      Italie
# 7           140     8         Marc Overmars                  Ajax    Pays-Bas
# 8           141     9       Matthias Sammer     Borussia Dortmund   Allemagne
# 9           142    10       Michael Laudrup           Real Madrid     Espagne
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1996 = pd.read_csv("players_90_99/tab_players_1996.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1996.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1996.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1996.at[0,'Club'] = 'Paris Saint-Germain'
# Modifier une cellule spécifique
#tab_players_1996.at[1,'Club'] = 'Tottenham Hotspur'
#tab_players_1996.at[26,'Club'] = 'Real Zaragoza'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens"]
hollande_liste=["Ajax","PSV Eindhoven"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1996['Club'].isin(france_liste)
spain_club = tab_players_1996['Club'].isin(espagne_liste)
italie_Club = tab_players_1996['Club'].isin(italie_liste)
allemagne_Club = tab_players_1996['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1996['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1996['Club'].isin(belguim_liste)
russie_Club = tab_players_1996['Club'].isin(russie_liste)
roumania_Club = tab_players_1996['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1996['Club'].isin(ukraine_liste)
greece_Club = tab_players_1996['Club'].isin(greece_liste)
hollande_Club = tab_players_1996['Club'].isin(hollande_liste)
portugal_Club = tab_players_1996['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_1996['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1996.loc[french_club, 'Country'] = 'France'
tab_players_1996.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1996.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1996.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1996.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1996.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1996.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1996.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1996.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1996.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1996.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1996.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_1996.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_1996.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1996.csv', sep = ',',header=True, index=False)
tab_players_1996
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom               Club  \
# 0           167     1       Matthias Sammer  Borussia Dortmund
# 1           168     2               Ronaldo      PSV Eindhoven
# 2           169     3          Alan Shearer   Blackburn Rovers
# 3           170     4  Alessandro Del Piero        Juventus FC
# 4           171     5      Jurgen Klinsmann      Bayern Munich
# 5           172     6           Davor Suker        Real Madrid
# 6           173     7          Eric Cantona  Manchester United
# 7           174     8       Marcel Desailly           Milan AC
# 8           175     9       Youri Djorkaeff        Inter Milan
# 9           176    10        Karel Poborsky      Slavia Prague
# 10          177    11          Nwankwo Kanu        Inter Milan
# 11          178    12           George Weah           Milan AC
# 12          179    13           Alen Boksic        Juventus FC
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1997 = pd.read_csv("players_90_99/tab_players_1997.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1997.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1997.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1997.at[0,'Club'] = 'Paris Saint-Germain'
# Modifier une cellule spécifique
#tab_players_1997.at[1,'Club'] = 'Tottenham Hotspur'
#tab_players_1997.at[26,'Club'] = 'Real Zaragoza'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern","Schalke 04",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens"]
hollande_liste=["Ajax","PSV Eindhoven"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1997['Club'].isin(france_liste)
spain_club = tab_players_1997['Club'].isin(espagne_liste)
italie_Club = tab_players_1997['Club'].isin(italie_liste)
allemagne_Club = tab_players_1997['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1997['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1997['Club'].isin(belguim_liste)
russie_Club = tab_players_1997['Club'].isin(russie_liste)
roumania_Club = tab_players_1997['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1997['Club'].isin(ukraine_liste)
greece_Club = tab_players_1997['Club'].isin(greece_liste)
hollande_Club = tab_players_1997['Club'].isin(hollande_liste)
portugal_Club = tab_players_1997['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_1997['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1997.loc[french_club, 'Country'] = 'France'
tab_players_1997.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1997.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1997.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1997.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1997.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1997.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1997.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1997.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1997.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1997.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1997.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_1997.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_1997.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1997.csv', sep = ',',header=True, index=False)
tab_players_1997
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom                 Club     Country  \
# 0           199     1               Ronaldo         FC Barcelone     Espagne
# 1           200     2     Predrag Mijatovic          Real Madrid     Espagne
# 2           201     3       Zinedine Zidane          Juventus FC      Italie
# 3           202     4       Dennis Bergkamp              Arsenal  Angleterre
# 4           203     5        Roberto Carlos          Real Madrid     Espagne
# 5           204     6        Andreas Moller    Borussia Dortmund   Allemagne
# 6           205     7                  Raul          Real Madrid     Espagne
# 7           206     8      Peter Schmeichel    Manchester United  Angleterre
# 8           207     9         Jurgen Kohler    Borussia Dortmund   Allemagne
# 9           208    10       Matthias Sammer    Borussia Dortmund   Allemagne
# 10          209    10       Christian Vieri      Atletico Madrid     Espagne
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1998 = pd.read_csv("players_90_99/tab_players_1998.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1998.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1998.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1998.at[0,'Club'] = 'Paris Saint-Germain'
# Modifier une cellule spécifique
#tab_players_1998.at[1,'Club'] = 'Tottenham Hotspur'
#tab_players_1998.at[26,'Club'] = 'Real Zaragoza'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern","Schalke 04",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1998['Club'].isin(france_liste)
spain_club = tab_players_1998['Club'].isin(espagne_liste)
italie_Club = tab_players_1998['Club'].isin(italie_liste)
allemagne_Club = tab_players_1998['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1998['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1998['Club'].isin(belguim_liste)
russie_Club = tab_players_1998['Club'].isin(russie_liste)
roumania_Club = tab_players_1998['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1998['Club'].isin(ukraine_liste)
greece_Club = tab_players_1998['Club'].isin(greece_liste)
hollande_Club = tab_players_1998['Club'].isin(hollande_liste)
portugal_Club = tab_players_1998['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_1998['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1998.loc[french_club, 'Country'] = 'France'
tab_players_1998.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1998.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1998.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1998.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1998.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1998.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1998.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1998.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1998.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1998.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1998.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_1998.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_1998.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1998.csv', sep = ',',header=True, index=False)
tab_players_1998
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom               Club     Country  \
# 0           235     1       Zinedine Zidane        Juventus FC      Italie
# 1           236     2           Davor Suker        Real Madrid     Espagne
# 2           237     3               Ronaldo        Inter Milan      Italie
# 3           238     4          Michael Owen          Liverpool  Angleterre
# 4           239     5               Rivaldo       FC Barcelone     Espagne
# 5           240     6     Gabriel Batistuta         Fiorentina      Italie
# 6           241     7         Lilian Thuram              Parma      Italie
# 7           242     8          Edgar Davids        Juventus FC      Italie
# 8           243     8       Dennis Bergkamp            Arsenal  Angleterre
# 9           244    10       Marcel Desailly            Chelsea  Angleterre
# 10          245    11         Frank de Boer               Ajax    Pays-Bas
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_1999 = pd.read_csv("players_90_99/tab_players_1999.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_1999.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_1999.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
#tab_players_1999.at[0,'Club'] = 'Paris Saint-Germain'
# Modifier une cellule spécifique
#tab_players_1999.at[1,'Club'] = 'Tottenham Hotspur'
#tab_players_1999.at[26,'Club'] = 'Real Zaragoza'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern","Schalke 04",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_1999['Club'].isin(france_liste)
spain_club = tab_players_1999['Club'].isin(espagne_liste)
italie_Club = tab_players_1999['Club'].isin(italie_liste)
allemagne_Club = tab_players_1999['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_1999['Club'].isin(angleterre_liste)
belguim_Club = tab_players_1999['Club'].isin(belguim_liste)
russie_Club = tab_players_1999['Club'].isin(russie_liste)
roumania_Club = tab_players_1999['Club'].isin(roumania_liste)
ukraine_Club = tab_players_1999['Club'].isin(ukraine_liste)
greece_Club = tab_players_1999['Club'].isin(greece_liste)
hollande_Club = tab_players_1999['Club'].isin(hollande_liste)
portugal_Club = tab_players_1999['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_1999['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1999.loc[french_club, 'Country'] = 'France'
tab_players_1999.loc[spain_club, 'Country'] = 'Espagne'
tab_players_1999.loc[italie_Club, 'Country'] = 'Italie'
tab_players_1999.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_1999.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_1999.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_1999.loc[russie_Club, 'Country'] = 'Russie'
tab_players_1999.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_1999.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_1999.loc[greece_Club, 'Country'] = 'Grece'
tab_players_1999.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_1999.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_1999.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_1999.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1999.csv', sep = ',',header=True, index=False)
tab_players_1999
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom               Club     Country  \
# 0           266     1               Rivaldo       FC Barcelone     Espagne
# 1           267     2         David Beckham  Manchester United  Angleterre
# 2           268     3     Andriy Shevchenko           Milan AC      Italie
# 3           269     4     Gabriel Batistuta         Fiorentina      Italie
# 4           270     5             Luis Figo       FC Barcelone     Espagne
# 5           271     6             Roy Keane  Manchester United  Angleterre
# 6           272     7       Christian Vieri              Lazio      Italie
# 7           273     8  Juan Sebastian Veron              Lazio      Italie
# 8           274     9                  Raul        Real Madrid     Espagne
# 9           275    10       Lothar Matthäus      Bayern Munich   Allemagne
# 10          276    11          Dwight Yorke  Manchester United  Angleterre
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_2000 = pd.read_csv("players_90_99/tab_players_2000.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_2000.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_2000.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_2000.at[27,'Club'] = 'Valencia'
# Modifier une cellule spécifique
#tab_players_2000.at[1,'Club'] = 'Tottenham Hotspur'
#tab_players_2000.at[26,'Club'] = 'Real Zaragoza'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese",
                "Milan AC","Inter Milan","Fiorentina","Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern","Schalke 04",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_2000['Club'].isin(france_liste)
spain_club = tab_players_2000['Club'].isin(espagne_liste)
italie_Club = tab_players_2000['Club'].isin(italie_liste)
allemagne_Club = tab_players_2000['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_2000['Club'].isin(angleterre_liste)
belguim_Club = tab_players_2000['Club'].isin(belguim_liste)
russie_Club = tab_players_2000['Club'].isin(russie_liste)
roumania_Club = tab_players_2000['Club'].isin(roumania_liste)
ukraine_Club = tab_players_2000['Club'].isin(ukraine_liste)
greece_Club = tab_players_2000['Club'].isin(greece_liste)
hollande_Club = tab_players_2000['Club'].isin(hollande_liste)
portugal_Club = tab_players_2000['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_2000['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2000.loc[french_club, 'Country'] = 'France'
tab_players_2000.loc[spain_club, 'Country'] = 'Espagne'
tab_players_2000.loc[italie_Club, 'Country'] = 'Italie'
tab_players_2000.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_2000.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_2000.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_2000.loc[russie_Club, 'Country'] = 'Russie'
tab_players_2000.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_2000.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_2000.loc[greece_Club, 'Country'] = 'Grece'
tab_players_2000.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_2000.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_2000.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_2000.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2000.csv', sep = ',',header=True, index=False)
tab_players_2000
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom               Club     Country  \
# 0           297     1             Luis Figo       FC Barcelone     Espagne
# 1           298     2       Zinedine Zidane        Juventus FC      Italie
# 2           299     3     Andriy Shevchenko           Milan AC      Italie
# 3           300     4         Thierry Henry            Arsenal  Angleterre
# 4           301     5      Alessandro Nesta              Lazio      Italie
# 5           302     6               Rivaldo       FC Barcelone     Espagne
# 6           303     7     Gabriel Batistuta               Roma      Italie
# 7           304     8       Gaizka Mendieta           Valencia     Espagne
# 8           305     9                  Raul        Real Madrid     Espagne
# 9           306    10         Paolo Maldini           Milan AC      Italie
# 10          307    10         David Beckham  Manchester United  Angleterre
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_2001 = pd.read_csv("players_90_99/tab_players_2001.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_2001.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_2001.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_2001.at[18,'Club'] = 'Valencia'
# Modifier une cellule spécifique
tab_players_2001.at[30,'Club'] = 'Parma'
tab_players_2001.at[42,'Club'] = 'Roma'
tab_players_2001.at[43,'Club'] = 'Lazio'
tab_players_2001.at[47,'Club'] = 'Parma'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen","Bordeaux","Lyon","Nantes"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese","Brescia",
                "Milan AC","Inter Milan","Fiorentina","Roma","A.S. Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern","Schalke 04",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_2001['Club'].isin(france_liste)
spain_club = tab_players_2001['Club'].isin(espagne_liste)
italie_Club = tab_players_2001['Club'].isin(italie_liste)
allemagne_Club = tab_players_2001['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_2001['Club'].isin(angleterre_liste)
belguim_Club = tab_players_2001['Club'].isin(belguim_liste)
russie_Club = tab_players_2001['Club'].isin(russie_liste)
roumania_Club = tab_players_2001['Club'].isin(roumania_liste)
ukraine_Club = tab_players_2001['Club'].isin(ukraine_liste)
greece_Club = tab_players_2001['Club'].isin(greece_liste)
hollande_Club = tab_players_2001['Club'].isin(hollande_liste)
portugal_Club = tab_players_2001['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_2001['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2001.loc[french_club, 'Country'] = 'France'
tab_players_2001.loc[spain_club, 'Country'] = 'Espagne'
tab_players_2001.loc[italie_Club, 'Country'] = 'Italie'
tab_players_2001.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_2001.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_2001.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_2001.loc[russie_Club, 'Country'] = 'Russie'
tab_players_2001.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_2001.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_2001.loc[greece_Club, 'Country'] = 'Grece'
tab_players_2001.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_2001.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_2001.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_2001.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2001.csv', sep = ',',header=True, index=False)
tab_players_2001
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                      Nom               Club     Country  \
# 0           327     1             Michael Owen          Liverpool  Angleterre
# 1           328     2                     Raul        Real Madrid     Espagne
# 2           329     3              Oliver Kahn      Bayern Munich   Allemagne
# 3           330     4            David Beckham  Manchester United  Angleterre
# 4           331     5          Francesco Totti          A.S. Roma      Italie
# 5           332     6                Luis Figo        Real Madrid     Espagne
# 6           333     7                  Rivaldo       FC Barcelone     Espagne
# 7           334     8        Andriy Shevchenko           Milan AC      Italie
# 8           335     9            Thierry Henry            Arsenal  Angleterre
# 9           336     9          Zinedine Zidane        Real Madrid     Espagne
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_2002 = pd.read_csv("players_90_99/tab_players_2002.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_2002.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_2002.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_2002.at[21,'Club'] = 'Lens'
# Modifier une cellule spécifique
#tab_players_2002.at[30,'Club'] = 'Parma'
#tab_players_2002.at[42,'Club'] = 'Roma'
#tab_players_2002.at[43,'Club'] = 'Lazio'
#tab_players_2002.at[47,'Club'] = 'Parma'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen","Bordeaux","Lyon","Nantes","Lens"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese","Brescia",
                "Milan AC","Inter Milan","Fiorentina","Roma","A.S. Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Hamburger SV", "Kaiserslautern","Schalke 04","Bayer Leverkusen",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_2002['Club'].isin(france_liste)
spain_club = tab_players_2002['Club'].isin(espagne_liste)
italie_Club = tab_players_2002['Club'].isin(italie_liste)
allemagne_Club = tab_players_2002['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_2002['Club'].isin(angleterre_liste)
belguim_Club = tab_players_2002['Club'].isin(belguim_liste)
russie_Club = tab_players_2002['Club'].isin(russie_liste)
roumania_Club = tab_players_2002['Club'].isin(roumania_liste)
ukraine_Club = tab_players_2002['Club'].isin(ukraine_liste)
greece_Club = tab_players_2002['Club'].isin(greece_liste)
hollande_Club = tab_players_2002['Club'].isin(hollande_liste)
portugal_Club = tab_players_2002['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_2002['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2002.loc[french_club, 'Country'] = 'France'
tab_players_2002.loc[spain_club, 'Country'] = 'Espagne'
tab_players_2002.loc[italie_Club, 'Country'] = 'Italie'
tab_players_2002.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_2002.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_2002.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_2002.loc[russie_Club, 'Country'] = 'Russie'
tab_players_2002.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_2002.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_2002.loc[greece_Club, 'Country'] = 'Grece'
tab_players_2002.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_2002.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_2002.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_2002.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2002.csv', sep = ',',header=True, index=False)
tab_players_2002
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom   Selection     Country  \
# 0           377     1               Ronaldo      Bresil      Italie
# 1           378     2        Roberto Carlos      Bresil     Espagne
# 2           379     3           Oliver Kahn   Allemagne   Allemagne
# 3           380     4       Zinedine Zidane      France     Espagne
# 4           381     5       Michael Ballack   Allemagne   Allemagne
# 5           382     6         Thierry Henry      France  Angleterre
# 6           383     7                  Raul     Espagne     Espagne
# 7           384     8               Rivaldo      Bresil     Espagne
# 8           385     9      Yıldıray Basturk     Turquie   Allemagne
# 9           386    10  Alessandro Del Piero      Italie      Italie
# 10          387    11             Hasan Sas     Turquie       neant
# 11          388    12            Ronaldinho      Bresil      France
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_2007 = pd.read_csv("players_90_99/tab_players_2007.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_2007.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_2007.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_2007.at[21,'Club'] = 'Lens'
# Modifier une cellule spécifique
#tab_players_2007.at[30,'Club'] = 'Parma'
#tab_players_2007.at[42,'Club'] = 'Roma'
#tab_players_2007.at[43,'Club'] = 'Lazio'
#tab_players_2007.at[47,'Club'] = 'Parma'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen","Bordeaux","Lyon","Nantes","Lens"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia",
                "Seville","Villarreal"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese","Brescia",
                "Milan AC","Inter Milan","Fiorentina","Roma","A.S. Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Werder Breme","Hamburger SV", "Kaiserslautern","Schalke 04","Bayer Leverkusen",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough","West Ham United",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_2007['Club'].isin(france_liste)
spain_club = tab_players_2007['Club'].isin(espagne_liste)
italie_Club = tab_players_2007['Club'].isin(italie_liste)
allemagne_Club = tab_players_2007['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_2007['Club'].isin(angleterre_liste)
belguim_Club = tab_players_2007['Club'].isin(belguim_liste)
russie_Club = tab_players_2007['Club'].isin(russie_liste)
roumania_Club = tab_players_2007['Club'].isin(roumania_liste)
ukraine_Club = tab_players_2007['Club'].isin(ukraine_liste)
greece_Club = tab_players_2007['Club'].isin(greece_liste)
hollande_Club = tab_players_2007['Club'].isin(hollande_liste)
portugal_Club = tab_players_2007['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_2007['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2007.loc[french_club, 'Country'] = 'France'
tab_players_2007.loc[spain_club, 'Country'] = 'Espagne'
tab_players_2007.loc[italie_Club, 'Country'] = 'Italie'
tab_players_2007.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_2007.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_2007.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_2007.loc[russie_Club, 'Country'] = 'Russie'
tab_players_2007.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_2007.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_2007.loc[greece_Club, 'Country'] = 'Grece'
tab_players_2007.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_2007.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_2007.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_2007.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2007.csv', sep = ',',header=True, index=False)
tab_players_2007
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                  Nom           Selection     Country  \
# 0           403     1                 Kaka              Bresil      Italie
# 1           404     2    Cristiano Ronaldo            Portugal  Angleterre
# 2           405     3         Lionel Messi           Argentine     Espagne
# 3           406     4        Didier Drogba       Cote d'ivoire  Angleterre
# 4           407     5         Andrea Pirlo              Italie      Italie
# 5           408     6  Ruud van Nistelrooy            Pays-Bas     Espagne
# 6           409     7   Zlatan Ibrahimovic               Suede      Italie
# 7           410     8        Cesc Fabregas             Espagne  Angleterre
# 8           411     9              Robinho              Bresil     Espagne
# 9           412    10      Francesco Totti              Italie      Italie
# 10          413    11     Frederic Kanoute                Mali     Espagne
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_2008 = pd.read_csv("players_90_99/tab_players_2008.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_2008.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_2008.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_2008.at[21,'Club'] = 'Lens'
# Modifier une cellule spécifique
#tab_players_2008.at[30,'Club'] = 'Parma'
#tab_players_2008.at[42,'Club'] = 'Roma'
#tab_players_2008.at[43,'Club'] = 'Lazio'
#tab_players_2008.at[47,'Club'] = 'Parma'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen","Bordeaux","Lyon","Nantes","Lens"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia",
                "Seville","Villarreal"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese","Brescia",
                "Milan AC","Inter Milan","Fiorentina","Roma","A.S. Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Werder Breme","Hamburger SV", "Kaiserslautern","Schalke 04","Bayer Leverkusen",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough","West Ham United",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade","CSKA Moscou","Zenit Saint Petersburg"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_2008['Club'].isin(france_liste)
spain_club = tab_players_2008['Club'].isin(espagne_liste)
italie_Club = tab_players_2008['Club'].isin(italie_liste)
allemagne_Club = tab_players_2008['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_2008['Club'].isin(angleterre_liste)
belguim_Club = tab_players_2008['Club'].isin(belguim_liste)
russie_Club = tab_players_2008['Club'].isin(russie_liste)
roumania_Club = tab_players_2008['Club'].isin(roumania_liste)
ukraine_Club = tab_players_2008['Club'].isin(ukraine_liste)
greece_Club = tab_players_2008['Club'].isin(greece_liste)
hollande_Club = tab_players_2008['Club'].isin(hollande_liste)
portugal_Club = tab_players_2008['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_2008['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2008.loc[french_club, 'Country'] = 'France'
tab_players_2008.loc[spain_club, 'Country'] = 'Espagne'
tab_players_2008.loc[italie_Club, 'Country'] = 'Italie'
tab_players_2008.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_2008.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_2008.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_2008.loc[russie_Club, 'Country'] = 'Russie'
tab_players_2008.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_2008.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_2008.loc[greece_Club, 'Country'] = 'Grece'
tab_players_2008.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_2008.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_2008.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_2008.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2008.csv', sep = ',',header=True, index=False)
tab_players_2008
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                   Nom      Selection     Country  \
# 0           453     1     Cristiano Ronaldo       Portugal  Angleterre
# 1           454     2          Lionel Messi      Argentine     Espagne
# 2           455     3       Fernando Torres        Espagne  Angleterre
# 3           456     4         Iker Casillas        Espagne     Espagne
# 4           457     5                  Xavi        Espagne     Espagne
# 5           458     6       Andrey Arshavin         Russie      Russie
# 6           459     7           David Villa        Espagne     Espagne
# 7           460     8    Zlatan Ibrahimovic          Suede      Italie
# 8           461     9                  Kaka         Bresil      Italie
# 9           462    10        Steven Gerrard     Angleterre  Angleterre
# 10          463    11          Marcos Senna        Espagne     Espagne
# ...

# %%
#Ouvrir et lire le csv necessaire
import pandas as pd

tab_players_2009 = pd.read_csv("players_90_99/tab_players_2009.csv")

# Ajouter une colonne au tableau de joueurs appeler "country" si elle n'existe pas
# Vérification de l'existence de la colonne
column_country = 'Country'
if column_country in tab_players_2009.columns:
    print(f"La colonne '{column_country}' existe dans le DataFrame.")
else:
    print(f"La colonne '{column_country}' n'existe pas dans le DataFrame.")
       # Ajouter une colonne au tableau de joueurs appeler "country" 
    tab_players_2009.insert(loc=4, column='Country', value='neant')


# Modifier une cellule spécifique
tab_players_2009.at[21,'Club'] = 'Lens'
# Modifier une cellule spécifique
#tab_players_2009.at[30,'Club'] = 'Parma'
#tab_players_2009.at[42,'Club'] = 'Roma'
#tab_players_2009.at[43,'Club'] = 'Lazio'
#tab_players_2009.at[47,'Club'] = 'Parma'

# Creer des listes par pays des differentes équipes
france_liste = ["Paris Saint-Germain","Nice","Marseille","Auxerre","Monaco","Caen","Bordeaux","Lyon","Nantes","Lens"]
espagne_liste = ["FC Barcelone","Atletico Madrid","Real Madrid","Barcelone","Deportivo La Corogne","Valencia","Sevilla",
                "Seville","Villarreal"]
italie_liste = ["Juventus FC","Sampdoria","Real Zaragoza","Udinese","Brescia",
                "Milan AC","Inter Milan","Fiorentina","Roma","A.S. Roma","Lazio","Naple","Torino","Pisa","Parma","Atalanta"]
allemagne_liste=["FC Cologne","Cologne","Werder Bremen","Werder Breme","Hamburger SV", "Kaiserslautern"
                 ,"Schalke 04","Bayer Leverkusen","Wolfsburg",
                 "Borussia Dortmund","VfB Stuttgart","Bayern Munich","Karlsruher SC","Borussia Mönchengladbach"]
angleterre_liste=["Liverpool","Celtic","Aberdeen","Derby County","Chelsea",
                  "Newcastle United","Leeds United","Blackburn Rovers","Middlesbrough","West Ham United",
                  "Tottenham Hotspur","Aston Villa","Nottingham Forest","Manchester United","Rangers","Arsenal"]
belguim_liste=["Mechelen","Standard Liege"]
russie_liste=["Red Star Belgrade","CSKA Moscou"]
roumania_liste=["Steauat Bucarest"]
RepTcheque_liste=["Slavia Prague"]
ukraine_liste=["Dynamo Kiev"]
portugal_liste=["Porto","FC Porto","Benfica","Sporting CP"]
greece_liste=["Panathinaikos","AEK Athens","Olympiacos"]
hollande_liste=["Ajax","PSV Eindhoven","Vitesse"]
#Je modify value of  country column
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
french_club = tab_players_2009['Club'].isin(france_liste)
spain_club = tab_players_2009['Club'].isin(espagne_liste)
italie_Club = tab_players_2009['Club'].isin(italie_liste)
allemagne_Club = tab_players_2009['Club'].isin(allemagne_liste)
angleterre_Club = tab_players_2009['Club'].isin(angleterre_liste)
belguim_Club = tab_players_2009['Club'].isin(belguim_liste)
russie_Club = tab_players_2009['Club'].isin(russie_liste)
roumania_Club = tab_players_2009['Club'].isin(roumania_liste)
ukraine_Club = tab_players_2009['Club'].isin(ukraine_liste)
greece_Club = tab_players_2009['Club'].isin(greece_liste)
hollande_Club = tab_players_2009['Club'].isin(hollande_liste)
portugal_Club = tab_players_2009['Club'].isin(portugal_liste)
RepTcheque_Club = tab_players_2009['Club'].isin(RepTcheque_liste)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2009.loc[french_club, 'Country'] = 'France'
tab_players_2009.loc[spain_club, 'Country'] = 'Espagne'
tab_players_2009.loc[italie_Club, 'Country'] = 'Italie'
tab_players_2009.loc[allemagne_Club, 'Country'] = 'Allemagne'
tab_players_2009.loc[angleterre_Club, 'Country'] = 'Angleterre'
tab_players_2009.loc[belguim_Club, 'Country'] = 'Belgique'
tab_players_2009.loc[russie_Club, 'Country'] = 'Russie'
tab_players_2009.loc[ukraine_Club, 'Country'] = 'Ukraine'
tab_players_2009.loc[roumania_Club, 'Country'] = 'Roumanie'
tab_players_2009.loc[greece_Club, 'Country'] = 'Grece'
tab_players_2009.loc[hollande_Club, 'Country'] = 'Pays-Bas'
tab_players_2009.loc[portugal_Club, 'Country'] = 'Portugal'
tab_players_2009.loc[RepTcheque_Club, 'Country'] = 'Republique-Tcheque'

 # ecrire un dataframe dans un fichier
tab_players_2009.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2009.csv', sep = ',',header=True, index=False)
tab_players_2009
# Out:
# La colonne 'Country' existe dans le DataFrame.
#     Primary_Key  Rank                 Nom               Selection     Country  \
# 0           483     1        Lionel Messi               Argentine     Espagne
# 1           484     2   Cristiano Ronaldo                Portugal  Angleterre
# 2           485     3                Xavi                 Espagne     Espagne
# 3           486     4      Andrés Iniesta                 Espagne     Espagne
# 4           487     5        Samuel Eto'o                Cameroun     Espagne
# 5           488     6                Kaka                  Bresil      Italie
# 6           489     7  Zlatan Ibrahimovic                   Suede      Italie
# 7           490     8        Wayne Rooney              Angleterre  Angleterre
# 8           491     9       Didier Drogba           Cote d'ivoire  Angleterre
# 9           492    10      Steven Gerrard              Angleterre  Angleterre
# ...
