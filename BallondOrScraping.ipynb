# %%
# !pip install requests
# !pip install lxml
# !pip install pandas
# !pip install numpy

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_all_pages():
    urls = []
    page_number=2015
    
    for url in range(2015,2022):
        url =(f"https://fr.wikipedia.org/wiki/Ballon_d%27or_{page_number}")
        page_number += 1
        urls.append(url)
    return urls
    
get_all_pages()

players = pd.DataFrame()
players_90_99 = pd.DataFrame()  
#def parse_players():
    
scraper = pd.read_html("https://fr.wikipedia.org/wiki/Ballon_d%27or_2016")
tab_players_2016 = scraper[2]
tab_players_2016 = tab_players_2016.rename(columns = {'%': 'Pourcentage_vote'})
tab_players_2016 = tab_players_2016.rename(columns = {'Sélection nationale': 'Selection'})

# remplace les symboles pourcentages dans la derniere colonne
tab_players_2016['Pourcentage_vote']= tab_players_2016['Pourcentage_vote'].str.replace('%','')
tab_players_2016['Pourcentage_vote']= tab_players_2016['Pourcentage_vote'].str.replace('\"','')
tab_players_2016['Club']= tab_players_2016['Club'].str.replace('Atlético','Atletico')
tab_players_2016['Selection']= tab_players_2016['Selection'].str.replace('Brésil','Bresil')
tab_players_2016['Selection']= tab_players_2016['Selection'].str.replace('Algérie','Algerie')
tab_players_2016['Selection']= tab_players_2016['Selection'].str.replace('Suède','Suede')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Suárez','Suarez')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Patrício','Patricio')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Modrić','Modric')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Agüero','Aguero')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Müller','Muller')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Higuaín','Higuain')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Godín','Godin')
tab_players_2016['Nom']= tab_players_2016['Nom'].str.replace('Andrés','Andres')
                # Modifier une cellule spécifique
tab_players_2016.at[12, 'Club'] = 'Paris Saint-Germain'
tab_players_2016.at[13, 'Club'] = 'Juventus FC'
tab_players_2016.at[23, 'Club'] = 'SSC Naples'
  
 # Générer une colonne de clé primaire
tab_players_2016.insert(loc=0, column='Primary_Key', value=range(1, len(tab_players_2016) + 1))
 # Add column 'Year' , 'confederation', 'type'
tab_players_2016['Year']='2016'
tab_players_2016.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2016['Type']='1' #(add 1 for UEFA by default)

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2016['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2016['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2016.loc[condition_CAF, 'Type'] = '2'
tab_players_2016.loc[condition_CONMEBOL, 'Type'] = '3'


# Add column Poste with value='Attaquant' for each row
tab_players_2016.insert(loc=4, column='Poste', value='Attaquant')
                ## Supprimer une colonne en utilisant del
                #del df['Col1']
               
                # write the dataframe in a csv file
tab_players_2016.to_csv(r'C:\Users\messj\Ballon_d_Or\players_2016_22\tab_players_2016.csv', sep = ',',header=True, index=False)
players = tab_players_2016
#return tab_players_2016
tab_players_2016


#parse_players()
# Out:
#     Primary_Key  Rang                        Nom                 Club  \
# 0             1     1          Cristiano Ronaldo          Real Madrid
# 1             2     2               Lionel Messi         FC Barcelone
# 2             3     3          Antoine Griezmann      Atletico Madrid
# 3             4     4                Luis Suarez         FC Barcelone
# 4             5     5                     Neymar         FC Barcelone
# 5             6     6                Gareth Bale          Real Madrid
# 6             7     7               Riyad Mahrez       Leicester City
# 7             8     8                Jamie Vardy       Leicester City
# 8             9     9           Gianluigi Buffon          Juventus FC
# 9            10     9                       Pepe          Real Madrid
# 10           11    11  Pierre-Emerick Aubameyang    Borussia Dortmund
# 11           12    12               Rui Patricio          Sporting CP
# ...

# %%
#def parse_players_2017():
scraper = pd.read_html("https://fr.wikipedia.org/wiki/Ballon_d%27or_2017")
tab_players_2017 = scraper[2]
tab_players_2017 = tab_players_2017.rename(columns = {'%': 'Pourcentage_vote'})
tab_players_2017 = tab_players_2017.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2017 = tab_players_2017.rename(columns = {'Joueur': 'Nom'})
    
# remplace les symboles pourcentages dans la derniere colonne
tab_players_2017['Pourcentage_vote']= tab_players_2017['Pourcentage_vote'].str.replace('%','')
tab_players_2017['Pourcentage_vote']= tab_players_2017['Pourcentage_vote'].str.replace('\"','')
tab_players_2017['Club']= tab_players_2017['Club'].str.replace('Atlético','Atletico')
tab_players_2017['Selection']= tab_players_2017['Selection'].str.replace('Brésil','Bresil')
tab_players_2017['Selection']= tab_players_2017['Selection'].str.replace('Algérie','Algerie')
tab_players_2017['Selection']= tab_players_2017['Selection'].str.replace('Suède','Suede')
tab_players_2017['Selection']= tab_players_2017['Selection'].str.replace('Sénégal','Senegal')
tab_players_2017['Selection']= tab_players_2017['Selection'].str.replace('Slovénie','Slovenie')
tab_players_2017['Selection']= tab_players_2017['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Suárez','Suarez')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Patrício','Patricio')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Modrić','Modric')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Agüero','Aguero')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Müller','Muller')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Higuaín','Higuain')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Mbappé','Mbappe')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Mané','Mane')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Kanté','Kante')
tab_players_2017['Nom']= tab_players_2017['Nom'].str.replace('Džeko','Dzeko')
# Modifier une cellule spécifique
tab_players_2017.at[6, 'Club'] = 'AS Monaco'
tab_players_2017.at[2, 'Club'] = 'FC Barcelone'
tab_players_2017.at[21, 'Club'] = 'Juventus FC'

#Add columns for conferation, type, Poste,Primary Key 
tab_players_2017.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2017['Type']='1' #(add 1 for UEFA by default)
tab_players_2017['Year']='2017'
tab_players_2017.insert(loc=0, column='Primary_Key', value=range(31, len(tab_players_2017) + 31))
tab_players_2017.insert(loc=4, column='Poste', value='Attaquant')
    ## Supprimer une colonne en utilisant del
    #del df['Col1']

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2017['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2017['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2017.loc[condition_CAF, 'Type'] = '2'
tab_players_2017.loc[condition_CONMEBOL, 'Type'] = '3'
   
    # write dataframe in a csv file
tab_players_2017.to_csv(r'C:\Users\messj\Ballon_d_Or\players_2016_22\tab_players_2017.csv', sep = ',',header=True, index=False)
tab_players_2017
    
    #return tab_players_2017

players = pd.concat([players,tab_players_2017])
players.to_csv('all_players.csv', sep=',', header=True, index=False)
tab_players_2017

#parse_players_2017()
# Out:
#     Primary_Key  Rang                        Nom                 Club  \
# 0            31     1          Cristiano Ronaldo          Real Madrid
# 1            32     2               Lionel Messi         FC Barcelone
# 2            33     3                     Neymar         FC Barcelone
# 3            34     4           Gianluigi Buffon          Juventus FC
# 4            35     5                Luka Modric          Real Madrid
# 5            36     6               Sergio Ramos          Real Madrid
# 6            37     7              Kylian Mbappe            AS Monaco
# 7            38     8               N'Golo Kante           Chelsea FC
# 8            39     9         Robert Lewandowski        Bayern Munich
# 9            40    10                 Harry Kane    Tottenham Hotspur
# 10           41    11             Edinson Cavani  Paris Saint-Germain
# 11           42    12                       Isco          Real Madrid
# ...

# %%
#def parse_players_2018():
    
scraper = pd.read_html("https://fr.wikipedia.org/wiki/Ballon_d%27or_2018")
tab_players_2018 = scraper[2]
tab_players_2018 = tab_players_2018.rename(columns = {'%': 'Pourcentage_vote'})
tab_players_2018 = tab_players_2018.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2018 = tab_players_2018.rename(columns = {'Joueur': 'Nom'})
    
# remplace les symboles pourcentages dans la derniere colonne
tab_players_2018['Pourcentage_vote']= tab_players_2018['Pourcentage_vote'].str.replace('%','')
tab_players_2018['Pourcentage_vote']= tab_players_2018['Pourcentage_vote'].str.replace('\"','')
tab_players_2018['Club']= tab_players_2018['Club'].str.replace('Atlético','Atletico')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Brésil','Bresil')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Algérie','Algerie')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Suède','Suede')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Sénégal','Senegal')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Slovénie','Slovenie')
tab_players_2018['Poste']= tab_players_2018['Poste'].str.replace('Défenseur','Defenseur')
tab_players_2018['Selection']= tab_players_2018['Selection'].str.replace('Égypte','Egypte')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Suárez','Suarez')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Patrício','Patricio')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Modrić','Modric')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Agüero','Aguero')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Müller','Muller')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Higuaín','Higuain')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Mbappé','Mbappe')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Mané','Mane')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Kanté','Kante')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Rakitić','Rakitic')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Mandžukić','Mandzukic')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Džeko','Dzeko') 
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Raphaël','Raphael')
tab_players_2018['Nom']= tab_players_2018['Nom'].str.replace('Godín','Godin')
    # Modifier une cellule spécifique
tab_players_2018.at[1, 'Club'] = 'Real Madrid'
tab_players_2018.at[13, 'Club'] = 'Chelsea FC'
tab_players_2018.at[24, 'Club'] = 'AS Rome' 
tab_players_2018.at[7, 'Poste'] = 'Milieu de terrain'
# Add columns for conferation , type, poste
tab_players_2018.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2018['Type']='1' #(add 1 for UEFA by default)
tab_players_2018['Year']='2018'
tab_players_2018.insert(loc=0, column='Primary_Key', value=range(61,len(tab_players_2018) + 61))
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2018['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2018['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2018.loc[condition_CAF, 'Type'] = '2'
tab_players_2018.loc[condition_CONMEBOL, 'Type'] = '3'   

    # ecrire un dataframe dans un fichier
tab_players_2018.to_csv(r'C:\Users\messj\Ballon_d_Or\players_2016_22\tab_players_2018.csv', sep = ',',header=True, index=False)
    
    #return tab_players_2018
players = pd.concat([players,tab_players_2018])
players.to_csv('all_players.csv', sep=',', header=True, index=False)
tab_players_2018

#parse_players_2018()
# Out:
#     Primary_Key  Rang                Nom                 Club       Selection  \
# 0            61     1        Luka Modric          Real Madrid         Croatie
# 1            62     2  Cristiano Ronaldo          Real Madrid        Portugal
# 2            63     3  Antoine Griezmann   Atletico de Madrid          France
# 3            64     4      Kylian Mbappe  Paris Saint-Germain          France
# 4            65     5       Lionel Messi         FC Barcelone       Argentine
# 5            66     6      Mohamed Salah         Liverpool FC          Egypte
# 6            67     7     Raphael Varane          Real Madrid          France
# 7            68     8        Eden Hazard           Chelsea FC        Belgique
# 8            69     9    Kevin De Bruyne      Manchester City        Belgique
# 9            70    10         Harry Kane    Tottenham Hotspur      Angleterre
# 10           71    11       N'Golo Kante           Chelsea FC          France
# ...

# %%
#def parse_players_2019():
    
scraper = pd.read_html("https://fr.wikipedia.org/wiki/Ballon_d%27or_2019")
tab_players_2019 = scraper[2]
tab_players_2019 = tab_players_2019.rename(columns = {'%': 'Pourcentage_vote'})
tab_players_2019 = tab_players_2019.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2019 = tab_players_2019.rename(columns = {'Joueur': 'Nom'})
    
# remplace les symboles pourcentages dans la derniere colonne
tab_players_2019['Pourcentage_vote']= tab_players_2019['Pourcentage_vote'].str.replace('%','')
tab_players_2019['Pourcentage_vote']= tab_players_2019['Pourcentage_vote'].str.replace('\"','')
tab_players_2019['Club']= tab_players_2019['Club'].str.replace('Atlético','Atletico')
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Brésil','Bresil') 
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Corée','Coree')
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Égypte','Egypte')
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Algérie','Algerie')
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Suède','Suede')
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2019['Selection']= tab_players_2019['Selection'].str.replace('Sénégal','Senegal')
tab_players_2019['Poste']= tab_players_2019['Poste'].str.replace('Défenseur','Defenseur')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Suárez','Suarez')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Patrício','Patricio')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Modrić','Modric')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Agüero','Aguero')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Müller','Muller')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Higuaín','Higuain')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Mbappé','Mbappe')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Mané','Mane')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Kanté','Kante')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Rakitić','Rakitic')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Mandžukić','Mandzukic')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Džeko','Dzeko')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Raphaël','Raphael')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('João Félix','Joao Felix')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Dušan Tadić','Dusan Tadic')
tab_players_2019['Nom']= tab_players_2019['Nom'].str.replace('Marc-André','Marc-Andre')
# Modifier une cellule spécifique
tab_players_2019.at[10, 'Club'] = 'Ajax Amsterdam'
tab_players_2019.at[14, 'Club'] = 'Ajax Amsterdam'
tab_players_2019.at[12, 'Club'] = 'Chelsea FC'
tab_players_2019.at[17, 'Club'] = 'Atletico de Madrid'
tab_players_2019.at[27, 'Club'] = 'Benfica Lisbonne'

# Add columns for conferation , type, poste
tab_players_2019.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2019['Type']='1' #(add 1 for UEFA by default)
tab_players_2019['Year']='2019'
tab_players_2019.insert(loc=0, column='Primary_Key', value=range(91,len(tab_players_2019) + 91))
    
    
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2019['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2019['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2019.loc[condition_CAF, 'Type'] = '2'
tab_players_2019.loc[condition_CONMEBOL, 'Type'] = '3'  
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
    #tab_players_2016.loc[tab_players_2016.index[12], 'Club'].str.replace('Paris Saint-Germain Manchester United','Manchester United')
    # ecrire un dataframe dans un fichier
tab_players_2019.to_csv(r'C:\Users\messj\Ballon_d_Or\players_2016_22\tab_players_2019.csv', sep = ',',header=True, index=False)
    
    #return tab_players_2019
players = pd.concat([players,tab_players_2019])
players.to_csv('all_players.csv', sep=',', header=True, index=False)
tab_players_2019  

#parse_players_2019()
# Out:
#     Primary_Key  Rang                        Nom                 Club  \
# 0            91     1               Lionel Messi         FC Barcelone
# 1            92     2            Virgil van Dijk         Liverpool FC
# 2            93     3          Cristiano Ronaldo          Juventus FC
# 3            94     4                 Sadio Mane         Liverpool FC
# 4            95     5              Mohamed Salah         Liverpool FC
# 5            96     6              Kylian Mbappe  Paris Saint-Germain
# 6            97     7                    Alisson         Liverpool FC
# 7            98     8         Robert Lewandowski        Bayern Munich
# 8            99     9             Bernardo Silva      Manchester City
# 9           100    10               Riyad Mahrez      Manchester City
# 10          101    11            Frenkie de Jong       Ajax Amsterdam
# 11          102    12            Raheem Sterling      Manchester City
# ...

# %%
#def parse_players_2021():
    
scraper = pd.read_html("https://fr.wikipedia.org/wiki/Ballon_d%27or_2021")
tab_players_2021 = scraper[2]
tab_players_2021 = tab_players_2021.rename(columns = {'%': 'Pourcentage_vote'})
tab_players_2021 = tab_players_2021.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2021 = tab_players_2021.rename(columns = {'Joueur': 'Nom'})
    
# remplace les symboles pourcentages dans la derniere colonne
tab_players_2021['Pourcentage_vote']= tab_players_2021['Pourcentage_vote'].str.replace('%','')
tab_players_2021['Pourcentage_vote']= tab_players_2021['Pourcentage_vote'].str.replace('\"','')
tab_players_2021['Club']= tab_players_2021['Club'].str.replace('Atlético','Atletico')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Brésil','Bresil') 
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Corée','Coree')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Égypte','Egypte')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Algérie','Algerie')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Suède','Suede')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Sénégal','Senegal')
tab_players_2021['Selection']= tab_players_2021['Selection'].str.replace('Norvège','Norvege')
tab_players_2021['Poste']= tab_players_2021['Poste'].str.replace('Défenseur','Defenseur')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Suárez','Suarez')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Patrício','Patricio')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Modrić','Modric')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Agüero','Aguero')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Müller','Muller')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Higuaín','Higuain')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Mbappé','Mbappe')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Mané','Mane')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Kanté','Kante')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Rakitić','Rakitic')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Mandžukić','Mandzukic')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Džeko','Dzeko')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Raphaël','Raphael')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('João Félix','Joao Felix')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Dušan Tadić','Dusan Tadic')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Marc-André','Marc-Andre')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Nicolò','Nicolo')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Rúben','Ruben ') 
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('César','Cesar ')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Martínez','Martinez')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Kjær','Kjaer')
# Modifier une cellule spécifique
tab_players_2021.at[5,'Club'] = 'Juventus FC'
tab_players_2021.at[0,'Club'] = 'FC Barcelone'
tab_players_2021.at[9,'Club'] = 'AC Milan'
tab_players_2021.at[11,'Club'] = 'Inter Milan'
# Add columns for conferation , type, poste,Primary_key
tab_players_2021.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2021['Type']='1' #(add 1 for UEFA by default)
tab_players_2021['Year']='2021'
tab_players_2021.insert(loc=0, column='Primary_Key', value=range(121,len(tab_players_2021) + 121))
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2021['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2021['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2021.loc[condition_CAF, 'Type'] = '2'
tab_players_2021.loc[condition_CONMEBOL, 'Type'] = '3'  

    # write  dataframe in a csv file
tab_players_2021.to_csv(r'C:\Users\messj\Ballon_d_Or\players_2016_22\tab_players_2021.csv', sep = ',',header=True, index=False)
    
    #return tab_players_2021
players = pd.concat([players,tab_players_2021])
players.to_csv('all_players.csv', sep=',', header=True, index=False)
tab_players_2021  

#parse_players_2021()
# Out:
#     Primary_Key  Rang                   Nom                Club   Selection  \
# 0           121     1          Lionel Messi        FC Barcelone   Argentine
# 1           122     2    Robert Lewandowski       Bayern Munich     Pologne
# 2           123     3              Jorginho          Chelsea FC      Italie
# 3           124     4         Karim Benzema         Real Madrid      France
# 4           125     5          N'Golo Kante          Chelsea FC      France
# 5           126     6     Cristiano Ronaldo         Juventus FC    Portugal
# 6           127     7         Mohamed Salah        Liverpool FC      Egypte
# 7           128     8       Kevin De Bruyne     Manchester City    Belgique
# 8           129     9         Kylian Mbappe            Paris SG      France
# 9           130    10  Gianluigi Donnarumma            AC Milan      Italie
# 10          131    11        Erling Haaland   Borussia Dortmund     Norvege
# ...

# %%
#def parse_players_2022():
    
scraper = pd.read_html("https://fr.wikipedia.org/wiki/Ballon_d%27or_2022")
tab_players_2022 = scraper[2]
tab_players_2022 = tab_players_2022.rename(columns = {'%': 'Pourcentage_vote'})
tab_players_2022 = tab_players_2022.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2022 = tab_players_2022.rename(columns = {'Joueur': 'Nom'})
    
# remplace les symboles pourcentages dans la derniere colonne
tab_players_2022['Pourcentage_vote']= tab_players_2022['Pourcentage_vote'].str.replace('%','')
tab_players_2022['Pourcentage_vote']= tab_players_2022['Pourcentage_vote'].str.replace('\"','')
tab_players_2022['Club']= tab_players_2022['Club'].str.replace('Atlético','Atletico')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Brésil','Bresil') 
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Corée','Coree')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Égypte','Egypte')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Algérie','Algerie')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Suède','Suede')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Sénégal','Senegal')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Norvège','Norvege')
tab_players_2022['Selection']= tab_players_2022['Selection'].str.replace('Côte','Cote')
tab_players_2022['Poste']= tab_players_2022['Poste'].str.replace('Défenseur','Defenseur')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Suárez','Suarez')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Patrício','Patricio')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Modrić','Modric')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Agüero','Aguero')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Müller','Muller')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Higuaín','Higuain')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Mbappé','Mbappe')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Mané','Mane')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Kanté','Kante')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Rakitić','Rakitic')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Mandžukić','Mandzukic')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Džeko','Dzeko')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Raphaël','Raphael')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('João Félix','Joao Felix')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Dušan Tadić','Dusan Tadic')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Marc-André','Marc-Andre')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Nicolò','Nicolo')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Rúben','Ruben') 
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('César','Cesar')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Vinícius Júnior','Vinicius Junior')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Leão','Leao')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Dušan Vlahović','Dusan Vlahovic')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Sébastien','Sebastien')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Núñez','Nunez')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('João','Joao')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Díaz','Diaz')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Rüdiger','Rudiger')
tab_players_2022['Nom']= tab_players_2022['Nom'].str.replace('Martínez','Martinez')


# Modifier une cellule spécifique
tab_players_2022.at[1,'Club'] = 'Liverpool FC'
tab_players_2022.at[3,'Club'] = 'Bayern Munich'
tab_players_2022.at[9,'Club'] = 'Borussia Dortmund'
tab_players_2022.at[12,'Club'] = 'Ajax Amsterdam'
tab_players_2022.at[16,'Club'] = 'Real Madrid'
tab_players_2022.at[17,'Club'] = 'ACF Fiorentina'
tab_players_2022.at[17,'Club'] = 'FC Porto'
tab_players_2022.at[27,'Club'] = 'Benfica Lisbonne'
tab_players_2022.at[29,'Club'] = 'Chelsea FC'

tab_players_2022['Year']='2022'
tab_players_2022.insert(loc=0, column='Primary_Key', value=range(151,len(tab_players_2022) + 151))
    # Add columns for conferation , type, poste,Primary_key
tab_players_2022.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2022['Type']='1' #(add 1 for UEFA by default)
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2022['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2022['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2022.loc[condition_CAF, 'Type'] = '2'
tab_players_2022.loc[condition_CONMEBOL, 'Type'] = '3'  
    
    # ecrire un dataframe dans un fichier
tab_players_2022.to_csv(r'C:\Users\messj\Ballon_d_Or\players_2016_22\tab_players_2022.csv', sep = ',',header=True, index=False)
    
    #return tab_players_2022
players = pd.concat([players,tab_players_2022])
players.to_csv('all_players.csv', sep=',', header=True, index=False)
tab_players_2022  

#parse_players_2022()
# Out:
#     Primary_Key  Rang                     Nom                   Club  \
# 0           151     1           Karim Benzema            Real Madrid
# 1           152     2              Sadio Mane           Liverpool FC
# 2           153     3         Kevin De Bruyne        Manchester City
# 3           154     4      Robert Lewandowski          Bayern Munich
# 4           155     5           Mohamed Salah           Liverpool FC
# 5           156     6           Kylian Mbappe    Paris Saint-Germain
# 6           157     7        Thibaut Courtois            Real Madrid
# 7           158     8         Vinicius Junior            Real Madrid
# 8           159     9             Luka Modric            Real Madrid
# 9           160    10          Erling Haaland      Borussia Dortmund
# 10          161    11           Son Heung-min      Tottenham Hotspur
# 11          162    12            Riyad Mahrez        Manchester City
# 12          163    13        Sebastien Haller         Ajax Amsterdam
# ...

# %%
#def parse_players_1990():
  
scraper = pd.read_html("https://en.wikipedia.org/wiki/1990_Ballon_d%27Or")
tab_players_1990 = scraper[0]
#tab_players_1990 = tab_players_1990.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1990 = tab_players_1990.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1990 = tab_players_1990.rename(columns = {'Name': 'Nom'})
tab_players_1990 = tab_players_1990.rename(columns = {'Club(s)': 'Club'})
tab_players_1990 = tab_players_1990.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1990['pourcentage_vote']= tab_players_1990['pourcentage_vote'].str.replace('%','')
#tab_players_1990['pourcentage_vote']= tab_players_1990['pourcentage_vote'].str.replace('\"','')
tab_players_1990['Club']= tab_players_1990['Club'].str.replace('Atlético','Atletico')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Brésil','Bresil') 
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Corée','Coree')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Égypte','Egypte')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Algérie','Algerie')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Suède','Suede')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Sénégal','Senegal')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Norvège','Norvege')
tab_players_1990['Selection']= tab_players_1990['Selection'].str.replace('Côte','Cote')
tab_players_1990['Club']= tab_players_1990['Club'].str.replace('Milan','Milan AC')
tab_players_1990['Club']= tab_players_1990['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1990['Club']= tab_players_1990['Club'].str.replace('Juventus','Juventus FC')
tab_players_1990['Club']= tab_players_1990['Club'].str.replace('Barcelona','Barcelone')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Martín Vázquez','Martin Vazquez')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Völler','Voller') 
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Higuaín','Higuain')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Mbappé','Mbappe')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Mané','Mane')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Kanté','Kante')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Rakitić','Rakitic')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Mandžukić','Mandzukic')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Džeko','Dzeko')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Raphaël','Raphael')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('João Félix','Joao Felix')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Dušan Tadić','Dusan Tadic')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Marc-André','Marc-Andre')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Nicolò','Nicolo')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Rúben','Ruben') 
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('César','Cesar')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Vinícius Júnior','Vinicius Junior')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Leão','Leao')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Dušan Vlahović','Dusan Vlahovic')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Sébastien','Sebastien')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Núñez','Nunez')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('João','Joao')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Díaz','Diaz')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Rüdiger','Rudiger')
tab_players_1990['Nom']= tab_players_1990['Nom'].str.replace('Martínez','Martinez')


# Modifier une cellule spécifique
#tab_players_1990.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year
tab_players_1990['Year']='1990'
tab_players_1990.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1990['Type']='1' #(add 1 for UEFA by default)
tab_players_1990.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1990.insert(loc=0, column='Primary_Key', value=range(1,len(tab_players_1990) + 1))
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']

    # write dataframe in csv file
tab_players_1990.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1990.csv', sep = ',',header=True, index=False)
tab_players_1990.to_json('tab_players_1990.json')
    
    #return tab_players_1990
players_90_99 = tab_players_1990
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1990  

#parse_players_1990()
# Out:
#     Primary_Key  Rank                    Nom                          Club  \
# 0             1     1        Lothar Matthaus                   Inter Milan
# 1             2     2    Salvatore Schillaci                   Juventus FC
# 2             3     3         Andreas Brehme                   Inter Milan
# 3             4     4         Paul Gascoigne             Tottenham Hotspur
# 4             5     5          Franco Baresi                      Milan AC
# 5             6     6             Enzo Scifo                       Auxerre
# 6             7     6       Jurgen Klinsmann                   Inter Milan
# 7             8     8         Roberto Baggio       Fiorentina  Juventus FC
# 8             9     9         Frank Rijkaard                      Milan AC
# 9            10    10         Guido Buchwald                 VfB Stuttgart
# 10           11    11      Jean-Pierre Papin                     Marseille
# ...

# %%
#def parse_players_1991():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1991_Ballon_d%27Or")
tab_players_1991 = scraper[0]
#tab_players_1991 = tab_players_1991.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1991 = tab_players_1991.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1991 = tab_players_1991.rename(columns = {'Name': 'Nom'})
tab_players_1991 = tab_players_1991.rename(columns = {'Club(s)': 'Club'})
tab_players_1991 = tab_players_1991.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1991['pourcentage_vote']= tab_players_1991['pourcentage_vote'].str.replace('%','')
#tab_players_1991['pourcentage_vote']= tab_players_1991['pourcentage_vote'].str.replace('\"','')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Atlético','Atletico')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Brésil','Bresil') 
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Corée','Coree')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Égypte','Egypte')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Algérie','Algerie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Suède','Suede')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Sénégal','Senegal')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Norvège','Norvege')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Côte','Cote')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Romania','Roumanie') 
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Corée','Coree')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Égypte','Egypte')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Germany','Allemagne')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Sweden','Suede')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Italy','Italie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Croatia','Croatie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Norway','Norvege')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Switzerland','Suisse')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Belgium','Belgique')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Austria','Australie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Russia','Russie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Greece','Grece')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Denmark','Danemark')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('England','Angleterre')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Yugoslavia','Yougoslavie')
tab_players_1991['Selection']= tab_players_1991['Selection'].str.replace('Spain','Espagne')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Milan','Milan AC')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Juventus','Juventus FC')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Barcelona','Barcelone')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Liège','Liege')
tab_players_1991['Club']= tab_players_1991['Club'].str.replace('Napoli','Naple')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Martín Vázquez','Martin Vazquez')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Völler','Voller') 
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Savićević','Savicevic')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Stéphane','Stephane')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Pančev','Pancev')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Kanté','Kante')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Rakitić','Rakitic')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Mandžukić','Mandzukic')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Džeko','Dzeko')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Raphaël','Raphael')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('João Félix','Joao Felix')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Dušan Tadić','Dusan Tadic')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Marc-André','Marc-Andre')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Nicolò','Nicolo')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Rúben','Ruben') 
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('César','Cesar')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Vinícius Júnior','Vinicius Junior')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Leão','Leao')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Dušan Vlahović','Dusan Vlahovic')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Sébastien','Sebastien')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Núñez','Nunez')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('João','Joao')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Díaz','Diaz')
tab_players_1991['Nom']= tab_players_1991['Nom'].str.replace('Rüdiger','Rudiger')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Martínez','Martinez')


# Modifier une cellule spécifique
#tab_players_1991.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year
tab_players_1991['Year']='1991'
tab_players_1991.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1991['Type']='1' #(add 1 for UEFA by default)

tab_players_1991.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1991.insert(loc=0, column='Primary_Key', value=range(24,len(tab_players_1991) + 24))
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
  
    # ecrire un dataframe dans un fichier
tab_players_1991.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1991.csv', sep = ',',header=True, index=False)
    
    #return tab_players_1991

players_90_99 = pd.concat([players_90_99,tab_players_1991])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1991  

#parse_players_1991()
# Out:
#     Primary_Key  Rank                    Nom       Selection  \
# 0            24     1      Jean-Pierre Papin          France
# 1            25     2        Dejan Savicevic     Yougoslavie
# 2            26     2           Darko Pancev     Yougoslavie
# 3            27     2        Lothar Matthaus       Allemagne
# 4            28     5      Robert Prosinecki     Yougoslavie
# 5            29     6           Gary Lineker      Angleterre
# 6            30     7        Gianluca Vialli          Italie
# 7            31     8     Miodrag Belodedici        Roumanie
# 8            32     9            Mark Hughes  Pays de Galles
# 9            33    10           Chris Waddle      Angleterre
# 10           34    11        Michael Laudrup        Danemark
# 11           35    12            Rudi Voller       Allemagne
# 12           36    13      Txiki Begiristain         Espagne
# 13           37    13     Stephane Chapuisat          Suisse
# ...

# %%
#def parse_players_1992():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1992_Ballon_d%27Or")
tab_players_1992 = scraper[0]
#tab_players_1992 = tab_players_1992.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1992 = tab_players_1992.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1992 = tab_players_1992.rename(columns = {'Name': 'Nom'})
tab_players_1992 = tab_players_1992.rename(columns = {'Club(s)': 'Club'})
tab_players_1992 = tab_players_1992.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1992['pourcentage_vote']= tab_players_1992['pourcentage_vote'].str.replace('%','')
#tab_players_1992['pourcentage_vote']= tab_players_1992['pourcentage_vote'].str.replace('\"','')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('Atlético','Atletico')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Brésil','Bresil') 
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Corée','Coree')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Égypte','Egypte')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Germany','Allemagne')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Sweden','Suede')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Italy','Italie')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Croatia','Croatie')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Norway','Norvege')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Switzerland','Suisse')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Belgium','Belgique')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Austria','Australie')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Russia','Russie')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Greece','Grece')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Denmark','Danemark')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('England','Angleterre')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1992['Selection']= tab_players_1992['Selection'].str.replace('Côte','Cote')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('Milan','Milan AC')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('Juventus','Juventus FC')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('Liège','Liege')
tab_players_1992['Club']= tab_players_1992['Club'].str.replace('1. FC Köln','FC Cologne')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Martín Vázquez','Martin Vazquez')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Völler','Voller') 
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Savićević','Savicevic')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Stéphane','Stephane')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Pančev','Pancev')
tab_players_1992['Nom']= tab_players_1992['Nom'].str.replace('Häßler','Hassler')
tab_players_2021['Nom']= tab_players_2021['Nom'].str.replace('Martínez','Martinez')


# Modifier une cellule spécifique
#tab_players_1992.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year
tab_players_1992['Year']='1992'
tab_players_1992.insert(loc=6, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1992['Type']='1' #(add 1 for UEFA by default)


tab_players_1992.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1992.insert(loc=0, column='Primary_Key', value=range(54,len(tab_players_1992) + 54))
# Supprimer une ligne spécifique en utilisant drop()
tab_players_1992 = tab_players_1992.drop(index=len(tab_players_1992)-1)

# Réindexer le DataFrame après la suppression
tab_players_1992 = tab_players_1992.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
    #tab_players_1992.loc[tab_players_1992.index[12], 'Club'].str.replace('Paris Saint-Germain Manchester United','Manchester United')
    # ecrire un dataframe dans un fichier
tab_players_1992.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1992.csv', sep = ',',header=True, index=False)

    #return tab_players_1992
players_90_99 = pd.concat([players_90_99,tab_players_1992])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1992  

#parse_players_1992()
# Out:
# C:\Users\messj\AppData\Local\Temp\ipykernel_12268\146926064.py:41: FutureWarning: The default value of regex will change from True to False in a future version.
#   tab_players_1992['Club']= tab_players_1992['Club'].str.replace('1. FC Köln','FC Cologne')
#     Primary_Key  Rank                 Nom               Club   Selection  \
# 0            54     1    Marco van Basten           Milan AC    Pays-Bas
# 1            55     2    Hristo Stoichkov       FC Barcelone    Bulgarie
# 2            56     3     Dennis Bergkamp               Ajax    Pays-Bas
# 3            57     4      Thomas Hassler               Roma   Allemagne
# 4            58     5    Peter Schmeichel  Manchester United    Danemark
# 5            59     6       Brian Laudrup         Fiorentina    Danemark
# 6            60     7     Michael Laudrup       FC Barcelone    Danemark
# 7            61     8       Ronald Koeman       FC Barcelone    Pays-Bas
# ...

# %%
#def parse_players_1993():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1993_Ballon_d%27Or")
tab_players_1993 = scraper[0]
#tab_players_1993 = tab_players_1993.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1993 = tab_players_1993.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1993 = tab_players_1993.rename(columns = {'Name': 'Nom'})
tab_players_1993 = tab_players_1993.rename(columns = {'Club(s)': 'Club'})
tab_players_1993 = tab_players_1993.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1993['pourcentage_vote']= tab_players_1993['pourcentage_vote'].str.replace('%','')
#tab_players_1993['pourcentage_vote']= tab_players_1993['pourcentage_vote'].str.replace('\"','')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('Atlético','Atletico')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Brésil','Bresil') 
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Germany','Allemagne')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Égypte','Egypte')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Sweden','Suede')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Italy','Italie')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Croatia','Croatie')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Norway','Norvege')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Switzerland','Suisse')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Belgium','Belgique')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Austria','Australie')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Russia','Russie')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Greece','Grece')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Denmark','Danemark')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('England','Angleterre')
tab_players_1993['Selection']= tab_players_1993['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('Milan','Milan AC')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('Juventus','Juventus FC')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('Liège','Liege')
tab_players_1993['Club']= tab_players_1993['Club'].str.replace('1. FC Köln','FC Cologne')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Martín Vázquez','Martin Vazquez')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Völler','Voller') 
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Savićević','Savicevic')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Stéphane','Stephane')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Pančev','Pancev')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Häßler','Hassler')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Bokšić','Boksic')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Sauzée','Sauzee')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Möller','Moller')
tab_players_1993['Nom']= tab_players_1993['Nom'].str.replace('Grun','Grun')

# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
#tab_players_1993.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1993.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1993['Type']='1' #(add 1 for UEFA by default)
tab_players_1993['Year']='1993'

tab_players_1993.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1993.insert(loc=0, column='Primary_Key', value=range(75,len(tab_players_1993) + 75))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1993 = tab_players_1993.drop(index=len(tab_players_1993))

# Réindexer le DataFrame après la suppression
#tab_players_1993 = tab_players_1993.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1993.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1993.csv', sep = ',',header=True, index=False)
 
players_90_99 = pd.concat([players_90_99,tab_players_1993])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1993  

#parse_players_1993()
# Out:
# C:\Users\messj\AppData\Local\Temp\ipykernel_12268\3922584885.py:39: FutureWarning: The default value of regex will change from True to False in a future version.
#   tab_players_1993['Club']= tab_players_1993['Club'].str.replace('1. FC Köln','FC Cologne')
#     Primary_Key  Rank                 Nom                      Club  \
# 0            75     1      Roberto Baggio               Juventus FC
# 1            76     2     Dennis Bergkamp               Inter Milan
# 2            77     3        Eric Cantona         Manchester United
# 3            78     4         Alen Boksic                     Lazio
# 4            79     5     Michael Laudrup              FC Barcelone
# 5            80     6       Franco Baresi                  Milan AC
# 6            81     7       Paolo Maldini                  Milan AC
# 7            82     8     Emil Kostadinov                     Porto
# 8            83     9  Stephane Chapuisat         Borussia Dortmund
# ...

# %%
#def parse_players_1994():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1994_Ballon_d%27Or")
tab_players_1994 = scraper[0]
#tab_players_1994 = tab_players_1994.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1994 = tab_players_1994.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1994 = tab_players_1994.rename(columns = {'Name': 'Nom'})
tab_players_1994 = tab_players_1994.rename(columns = {'Club(s)': 'Club'})
tab_players_1994 = tab_players_1994.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1994['pourcentage_vote']= tab_players_1994['pourcentage_vote'].str.replace('%','')
#tab_players_1994['pourcentage_vote']= tab_players_1994['pourcentage_vote'].str.replace('\"','')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('Atlético','Atletico')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Brésil','Bresil') 
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Germany','Allemagne')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Égypte','Egypte')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Sweden','Suede')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Italy','Italie')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Croatia','Croatie')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Norway','Norvege')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Switzerland','Suisse')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Belgium','Belgique')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Austria','Australie')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Russia','Russie')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Greece','Grece')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Denmark','Danemark')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('England','Angleterre')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('Spain','Espagne')
tab_players_1994['Selection']= tab_players_1994['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('Milan','Milan AC')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('Juventus','Juventus FC')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('Liège','Liege')
tab_players_1994['Club']= tab_players_1994['Club'].str.replace('1. FC Köln','FC Cologne')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Martín Vázquez','Martin Vazquez')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Völler','Voller') 
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Savićević','Savicevic')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Stéphane','Stephane')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Pančev','Pancev')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Häßler','Hassler')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Bokšić','Boksic')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Sauzée','Sauzee')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Möller','Moller')
tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Krasimir Balakov[notes 1]','Krasimir Balakov')

# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_1994.at[15,'Nom'] = 'Krasimir Balakov'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1994.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1994['Type']='1' #(add 1 for UEFA by default)
tab_players_1994['Year']='1994'

tab_players_1994.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1994.insert(loc=0, column='Primary_Key', value=range(105,len(tab_players_1994) + 105))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1994 = tab_players_1994.drop(index=len(tab_players_1994))

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1994['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1994['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1994.loc[condition_CAF, 'Type'] = '2'
tab_players_1994.loc[condition_CONMEBOL, 'Type'] = '3'  

# Réindexer le DataFrame après la suppression
#tab_players_1994 = tab_players_1994.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1994.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1994.csv', sep = ',',header=True, index=False)

   
players_90_99 = pd.concat([players_90_99,tab_players_1994])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1994  

#parse_players_1994()
# Out:
# C:\Users\messj\AppData\Local\Temp\ipykernel_12268\2517235799.py:41: FutureWarning: The default value of regex will change from True to False in a future version.
#   tab_players_1994['Club']= tab_players_1994['Club'].str.replace('1. FC Köln','FC Cologne')
# C:\Users\messj\AppData\Local\Temp\ipykernel_12268\2517235799.py:55: FutureWarning: The default value of regex will change from True to False in a future version.
#   tab_players_1994['Nom']= tab_players_1994['Nom'].str.replace('Krasimir Balakov[notes 1]','Krasimir Balakov')
#     Primary_Key  Rank                 Nom    Selection  \
# 0           105     1    Hristo Stoichkov     Bulgarie
# 1           106     2      Roberto Baggio       Italie
# 2           107     3       Paolo Maldini       Italie
# 3           108     4       Gheorghe Hagi      Romania
# 4           109     4        Tomas Brolin        Suede
# 5           110     6    Jurgen Klinsmann    Allemagne
# 6           111     7      Thomas Ravelli        Suede
# ...

# %%
#def parse_players_1995():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1995_Ballon_d%27Or")
tab_players_1995 = scraper[0]
#tab_players_1995 = tab_players_1995.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1995 = tab_players_1995.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1995 = tab_players_1995.rename(columns = {'Name': 'Nom'})
tab_players_1995 = tab_players_1995.rename(columns = {'Club(s)': 'Club'})
tab_players_1995 = tab_players_1995.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1995['pourcentage_vote']= tab_players_1995['pourcentage_vote'].str.replace('%','')
#tab_players_1995['pourcentage_vote']= tab_players_1995['pourcentage_vote'].str.replace('\"','')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('Atlético','Atletico')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Brésil','Bresil') 
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Germany','Allemagne')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Égypte','Egypte')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Sweden','Suede')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Italy','Italie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Croatia','Croatie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Norway','Norvege')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Switzerland','Suisse')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Belgium','Belgique')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Austria','Australie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Russia','Russie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Greece','Grece')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Denmark','Danemark')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('England','Angleterre')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Spain','Espagne')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Yugoslavia','Yougoslavie')
tab_players_1995['Selection']= tab_players_1995['Selection'].str.replace('Argentina','Argentine')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('Milan','Milan AC')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('Juventus','Juventus FC')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('Liège','Liege')
tab_players_1995['Club']= tab_players_1995['Club'].str.replace('La Coruña','La Corogne')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Esnáider','Esnaider')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Martín Vázquez','Martin Vazquez')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Völler','Voller') 
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Savićević','Savicevic')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Luís','Luis')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Pančev','Pancev')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Häßler','Hassler')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Bokšić','Boksic')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Šuker','Suker')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Möller','Moller')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Iván','Ivan')
tab_players_1995['Nom']= tab_players_1995['Nom'].str.replace('Vítor Baía','Vitor Baia')

# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
#tab_players_1995.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1995.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1995['Type']='1' #(add 1 for UEFA by default)
tab_players_1995['Year']='1995'

tab_players_1995.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1995.insert(loc=0, column='Primary_Key', value=range(133,len(tab_players_1995) + 133))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1995 = tab_players_1995.drop(index=len(tab_players_1995))

# Réindexer le DataFrame après la suppression
#tab_players_1995 = tab_players_1995.reset_index(drop=True)
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1995['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1995['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1995.loc[condition_CAF, 'Type'] = '2'
tab_players_1995.loc[condition_CONMEBOL, 'Type'] = '3'  
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1995.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1995.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_1995])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1995  

#parse_players_1995()
# Out:
#     Primary_Key  Rank                   Nom  \
# 0           133     1           George Weah
# 1           134     2      Jurgen Klinsmann
# 2           135     3         Jari Litmanen
# 3           136     4  Alessandro Del Piero
# 4           137     5      Patrick Kluivert
# 5           138     6       Gianfranco Zola
# 6           139     7         Paolo Maldini
# 7           140     8         Marc Overmars
# 8           141     9       Matthias Sammer
# 9           142    10       Michael Laudrup
# 10          143    11       Marcel Desailly
# 11          144    12        Frank Rijkaard
# 12          145    12    Fabrizio Ravanelli
# 13          146    14           Paulo Sousa
# 14          147    14      Hristo Stoichkov
# 15          148    16       Dejan Savicevic
# 16          149    17           Davor Suker
# 17          150    18       Fernando Hierro
# 18          151    19       Gianluca Vialli
# 19          152    20     Gabriel Batistuta
# ...

# %%
#def parse_players_1996():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1996_Ballon_d%27Or")
tab_players_1996 = scraper[0]
#tab_players_1996 = tab_players_1996.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1996 = tab_players_1996.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1996 = tab_players_1996.rename(columns = {'Name': 'Nom'})
tab_players_1996 = tab_players_1996.rename(columns = {'Club(s)': 'Club'})
tab_players_1996 = tab_players_1996.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1996['pourcentage_vote']= tab_players_1996['pourcentage_vote'].str.replace('%','')
#tab_players_1996['pourcentage_vote']= tab_players_1996['pourcentage_vote'].str.replace('\"','')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Atlético','Atletico')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Brésil','Bresil') 
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Brazil','Bresil')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Germany','Allemagne')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Égypte','Egypte')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Sweden','Suede')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Italy','Italie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Croatia','Croatie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Norway','Norvege')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Switzerland','Suisse')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Belgium','Belgique')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Austria','Australie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Russia','Russie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Greece','Grece')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Denmark','Danemark')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('England','Angleterre')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Spain','Espagne')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Yugoslavia','Yougoslavie')
tab_players_1996['Selection']= tab_players_1996['Selection'].str.replace('Argentina','Argentine')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Milan','Milan AC')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Juventus','Juventus FC')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Liège','Liege')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('Rapid Wien','Rapid Vienne')
tab_players_1996['Club']= tab_players_1996['Club'].str.replace('La Coruña','La Corogne')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Poborský','Poborsky')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Savićević','Savicevic')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Luís','Luis')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Köpke','Kopke')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Häßler','Hassler')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Bokšić','Boksic')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Šuker','Suker')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Türkyilmaz','Turkyilmaz')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Iván','Ivan')
tab_players_1996['Nom']= tab_players_1996['Nom'].str.replace('Raúl','Raul')
#tab_players_1996['Points']= tab_players_1996['Points'].str.replace('[note 1]','')
#tab_players_1996['Points']= tab_players_1996['Points'].str.replace('[note 2]','')
#tab_players_1996['Points']= tab_players_1996['Points'].str.replace('[note 3]','')
#tab_players_1996['Points']= tab_players_1996['Points'].str.replace('[note 4]','')
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_1996.at[1,'Club'] = 'PSV Eindhoven'
tab_players_1996.at[2,'Club'] = 'Blackburn Rovers'
tab_players_1996.at[9,'Club'] = 'Slavia Prague' 
tab_players_1996.at[23,'Club'] = 'Borussia Dortmund'
tab_players_1996.at[25,'Club'] = 'Slavia Prague'
tab_players_1996.at[1,'Points'] = '143'
tab_players_1996.at[2,'Points'] = '107'
tab_players_1996.at[3,'Points'] = '69'
tab_players_1996.at[11,'Points'] = '13'
# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1996.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1996['Type']='1' #(add 1 for UEFA by default)
tab_players_1996['Year']='1996'

tab_players_1996.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1996.insert(loc=0, column='Primary_Key', value=range(167,len(tab_players_1996) + 167))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1996 = tab_players_1996.drop(index=len(tab_players_1996))

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1996['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1996['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1996.loc[condition_CAF, 'Type'] = '2'
tab_players_1996.loc[condition_CONMEBOL, 'Type'] = '3' 

# Réindexer le DataFrame après la suppression
#tab_players_1996 = tab_players_1996.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1996.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1996.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_1996])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1996  

#parse_players_1996()
# Out:
#     Primary_Key  Rank                   Nom               Club  \
# 0           167     1       Matthias Sammer  Borussia Dortmund
# 1           168     2               Ronaldo      PSV Eindhoven
# 2           169     3          Alan Shearer   Blackburn Rovers
# 3           170     4  Alessandro Del Piero        Juventus FC
# 4           171     5      Jurgen Klinsmann      Bayern Munich
# 5           172     6           Davor Suker        Real Madrid
# 6           173     7          Eric Cantona  Manchester United
# 7           174     8       Marcel Desailly           Milan AC
# 8           175     9       Youri Djorkaeff        Inter Milan
# 9           176    10        Karel Poborsky      Slavia Prague
# 10          177    11          Nwankwo Kanu        Inter Milan
# 11          178    12           George Weah           Milan AC
# 12          179    13           Alen Boksic        Juventus FC
# 13          180    13     Gabriel Batistuta         Fiorentina
# ...

# %%
#def parse_players_1997():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1997_Ballon_d%27Or")
tab_players_1997 = scraper[0]
#tab_players_1997 = tab_players_1997.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1997 = tab_players_1997.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1997 = tab_players_1997.rename(columns = {'Name': 'Nom'})
tab_players_1997 = tab_players_1997.rename(columns = {'Club(s)': 'Club'})
tab_players_1997 = tab_players_1997.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1997['pourcentage_vote']= tab_players_1997['pourcentage_vote'].str.replace('%','')
#tab_players_1997['pourcentage_vote']= tab_players_1997['pourcentage_vote'].str.replace('\"','')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('Atlético','Atletico')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Brésil','Bresil') 
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Germany','Allemagne')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Égypte','Egypte')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Sweden','Suede')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Italy','Italie')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Croatia','Croatie')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Norway','Norvege')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Switzerland','Suisse')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Belgium','Belgique')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Austria','Australie')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Russia','Russie')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Greece','Grece')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Denmark','Danemark')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('England','Angleterre')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Spain','Espagne')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1997['Selection']= tab_players_1997['Selection'].str.replace('Argentina','Argentine')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('Milan','Milan AC')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('Juventus','Juventus FC')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('Liège','Liege')
tab_players_1997['Club']= tab_players_1997['Club'].str.replace('La Coruña','La Corogne')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Möller','Moller')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Poborský','Poborsky')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Savićević','Savicevic')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Luís','Luis')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Köpke','Kopke')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Häßler','Hassler')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Bokšić','Boksic')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Šuker','Suker')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Raí','Rai')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Iván','Ivan')
tab_players_1997['Nom']= tab_players_1997['Nom'].str.replace('Raúl','Raul')

# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_1997.at[0,'Club'] = 'FC Barcelone'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1997.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1997['Type']='1' #(add 1 for UEFA by default)
tab_players_1997['Year']='1997'

tab_players_1997.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1997.insert(loc=0, column='Primary_Key', value=range(199,len(tab_players_1997) + 199))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1997 = tab_players_1997.drop(index=len(tab_players_1997))

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1997['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1997['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1997.loc[condition_CAF, 'Type'] = '2'
tab_players_1997.loc[condition_CONMEBOL, 'Type'] = '3' 

# Réindexer le DataFrame après la suppression
#tab_players_1997 = tab_players_1997.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1997.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1997.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_1997])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1997  

#parse_players_1997()
# Out:
#     Primary_Key  Rank                   Nom                 Club  \
# 0           199     1               Ronaldo         FC Barcelone
# 1           200     2     Predrag Mijatovic          Real Madrid
# 2           201     3       Zinedine Zidane          Juventus FC
# 3           202     4       Dennis Bergkamp              Arsenal
# 4           203     5        Roberto Carlos          Real Madrid
# 5           204     6        Andreas Moller    Borussia Dortmund
# 6           205     7                  Raul          Real Madrid
# 7           206     8      Peter Schmeichel    Manchester United
# 8           207     9         Jurgen Kohler    Borussia Dortmund
# 9           208    10       Matthias Sammer    Borussia Dortmund
# 10          209    10       Christian Vieri      Atletico Madrid
# 11          210    12       Youri Djorkaeff          Inter Milan
# 12          211    13          Luis Enrique         FC Barcelone
# ...

# %%
#def parse_players_1998():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1998_Ballon_d%27Or")
tab_players_1998 = scraper[0]
#tab_players_1998 = tab_players_1998.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1998 = tab_players_1998.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1998 = tab_players_1998.rename(columns = {'Name': 'Nom'})
tab_players_1998 = tab_players_1998.rename(columns = {'Club(s)': 'Club'})
tab_players_1998 = tab_players_1998.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1998['pourcentage_vote']= tab_players_1998['pourcentage_vote'].str.replace('%','')
#tab_players_1998['pourcentage_vote']= tab_players_1998['pourcentage_vote'].str.replace('\"','')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('Atlético','Atletico')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Brésil','Bresil') 
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Germany','Allemagne')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Égypte','Egypte')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Sweden','Suede')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Italy','Italie')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Croatia','Croatie')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Norway','Norvege')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Switzerland','Suisse')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Belgium','Belgique')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Austria','Australie')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Russia','Russie')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Greece','Grece')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Denmark','Danemark')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('England','Angleterre')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Spain','Espagne')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1998['Selection']= tab_players_1998['Selection'].str.replace('Argentina','Argentine')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('Milan','Milan AC')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('Juventus','Juventus FC')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('Liège','Liege')
tab_players_1998['Club']= tab_players_1998['Club'].str.replace('La Coruña','La Corogne')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Möller','Moller')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Poborský','Poborsky')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Savićević','Savicevic')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Luís','Luis')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Köpke','Kopke')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Häßler','Hassler')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Bokšić','Boksic')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Šuker','Suker')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Raí','Rai')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Iván','Ivan')
tab_players_1998['Nom']= tab_players_1998['Nom'].str.replace('Raúl','Raul')

# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
#tab_players_1998.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1998.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1998['Type']='1' #(add 1 for UEFA by default)
tab_players_1998['Year']='1998'

tab_players_1998.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1998.insert(loc=0, column='Primary_Key', value=range(235,len(tab_players_1998) + 235))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1998 = tab_players_1998.drop(index=len(tab_players_1998))

# Réindexer le DataFrame après la suppression
#tab_players_1998 = tab_players_1998.reset_index(drop=True)
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1998['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1998['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1998.loc[condition_CAF, 'Type'] = '2'
tab_players_1998.loc[condition_CONMEBOL, 'Type'] = '3'

    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1998.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1998.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_1998])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1998  

#parse_players_1998()
# Out:
#     Primary_Key  Rank                   Nom               Club   Selection  \
# 0           235     1       Zinedine Zidane        Juventus FC      France
# 1           236     2           Davor Suker        Real Madrid     Croatie
# 2           237     3               Ronaldo        Inter Milan      Brazil
# 3           238     4          Michael Owen          Liverpool  Angleterre
# 4           239     5               Rivaldo       FC Barcelone      Brazil
# 5           240     6     Gabriel Batistuta         Fiorentina   Argentine
# 6           241     7         Lilian Thuram              Parma      France
# 7           242     8          Edgar Davids        Juventus FC    Pays-Bas
# 8           243     8       Dennis Bergkamp            Arsenal    Pays-Bas
# 9           244    10       Marcel Desailly            Chelsea      France
# 10          245    11         Frank de Boer               Ajax    Pays-Bas
# ...

# %%
#def parse_players_1999():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1999_Ballon_d%27Or")
tab_players_1999 = scraper[0]
#tab_players_1999 = tab_players_1999.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1999 = tab_players_1999.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1999 = tab_players_1999.rename(columns = {'Name': 'Nom'})
tab_players_1999 = tab_players_1999.rename(columns = {'Club(s)': 'Club'})
tab_players_1999 = tab_players_1999.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1999['pourcentage_vote']= tab_players_1999['pourcentage_vote'].str.replace('%','')
#tab_players_1999['pourcentage_vote']= tab_players_1999['pourcentage_vote'].str.replace('\"','')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('Atlético','Atletico')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Brésil','Bresil') 
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Germany','Allemagne')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Égypte','Egypte')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Sweden','Suede')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Italy','Italie')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Croatia','Croatie')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Norway','Norvege')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Switzerland','Suisse')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Belgium','Belgique')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Austria','Australie')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Russia','Russie')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Greece','Grece')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Denmark','Danemark')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('England','Angleterre')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Spain','Espagne')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1999['Selection']= tab_players_1999['Selection'].str.replace('Argentina','Argentine')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('Milan','Milan AC')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('Juventus','Juventus FC')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('Liège','Liege')
tab_players_1999['Club']= tab_players_1999['Club'].str.replace('La Coruña','La Corogne')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Möller','Moller')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Poborský','Poborsky')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Savićević','Savicevic')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Luís','Luis')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Köpke','Kopke')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Zahovič','Zahovic')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Mário','Mario')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Šuker','Suker')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('López','Lopez')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Nedvěd','Nedved')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Raúl','Raul')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Sebastián Verón','Sebastian Veron')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Matthaus','Matthaus')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Siniša','Sinisa')
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Hernán','Hernan')	
tab_players_1999['Nom']= tab_players_1999['Nom'].str.replace('Mihajlović','Mihajlovic')
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
#tab_players_1999.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1999.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1999['Type']='1' #(add 1 for UEFA by default)
tab_players_1999['Year']='1999'

tab_players_1999.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1999.insert(loc=0, column='Primary_Key', value=range(266,len(tab_players_1999) + 266))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1999 = tab_players_1999.drop(index=len(tab_players_1999))

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1999['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1999['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1999.loc[condition_CAF, 'Type'] = '2'
tab_players_1999.loc[condition_CONMEBOL, 'Type'] = '3'

# Réindexer le DataFrame après la suppression
#tab_players_1999 = tab_players_1999.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1999.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1999.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_1999])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1999  

#parse_players_1999()
# Out:
#     Primary_Key  Rank                   Nom               Club  \
# 0           266     1               Rivaldo       FC Barcelone
# 1           267     2         David Beckham  Manchester United
# 2           268     3     Andriy Shevchenko           Milan AC
# 3           269     4     Gabriel Batistuta         Fiorentina
# 4           270     5             Luis Figo       FC Barcelone
# 5           271     6             Roy Keane  Manchester United
# 6           272     7       Christian Vieri              Lazio
# 7           273     8  Juan Sebastian Veron              Lazio
# 8           274     9                  Raul        Real Madrid
# 9           275    10       Lothar Matthäus      Bayern Munich
# 10          276    11          Dwight Yorke  Manchester United
# 11          277    12             Jaap Stam  Manchester United
# 12          278    13     Sinisa Mihajlovic              Lazio
# 13          279    14        Zlatko Zahovic         Olympiacos
# ...

# %%
#def parse_players_2000():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/2000_Ballon_d%27Or")
tab_players_2000 = scraper[0]
#tab_players_2000 = tab_players_2000.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_2000 = tab_players_2000.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2000 = tab_players_2000.rename(columns = {'Name': 'Nom'})
tab_players_2000 = tab_players_2000.rename(columns = {'Club(s)': 'Club'})
tab_players_2000 = tab_players_2000.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_2000['pourcentage_vote']= tab_players_2000['pourcentage_vote'].str.replace('%','')
#tab_players_2000['pourcentage_vote']= tab_players_2000['pourcentage_vote'].str.replace('\"','')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('Atlético','Atletico')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Brésil','Bresil') 
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Germany','Allemagne')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Égypte','Egypte')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Sweden','Suede')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Italy','Italie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Croatia','Croatie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Norway','Norvege')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Switzerland','Suisse')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Belgium','Belgique')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Austria','Australie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Russia','Russie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Greece','Grece')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Wales','Pays de Galles')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Denmark','Danemark')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('England','Angleterre')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Spain','Espagne')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Argentina','Argentine')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Slovenia','Slovenie')
tab_players_2000['Selection']= tab_players_2000['Selection'].str.replace('Brazil','Bresil')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('Milan','Milan AC')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('Internazionale','Inter Milan')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('Juventus','Juventus FC')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('Liège','Liege')
tab_players_2000['Club']= tab_players_2000['Club'].str.replace('La Coruña','La Corogne')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Möller','Moller')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Poborský','Poborsky')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Stojković','Stojkovic')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Jürgen','Jurgen')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Savićević','Savicevic')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Luís','Luis')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Şükür','Sukur')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Zahovič','Zahovic')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Mário','Mario')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Šuker','Suker')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('López','Lopez')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Nedvěd','Nedved')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Raúl','Raul')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Sebastián Verón','Sebastian Veron')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Matthaus','Matthaus')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Siniša','Sinisa')
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Hernán','Hernan')	
tab_players_2000['Nom']= tab_players_2000['Nom'].str.replace('Mihajlović','Mihajlovic')
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_2000.at[0,'Club'] = 'FC Barcelone'
tab_players_2000.at[20,'Club'] = 'Real Madrid'
tab_players_2000.at[11,'Club'] = 'Olympiacos'
# Add columns for conferation , type, poste,Primary_key, Year

tab_players_2000.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2000['Type']='1' #(add 1 for UEFA by default)
tab_players_2000['Year']='2000'

tab_players_2000.insert(loc=4, column='Poste', value='Attaquant')
tab_players_2000.insert(loc=0, column='Primary_Key', value=range(297,len(tab_players_2000) + 297))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_2000 = tab_players_2000.drop(index=len(tab_players_2000))

# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2000['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2000['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2000.loc[condition_CAF, 'Type'] = '2'
tab_players_2000.loc[condition_CONMEBOL, 'Type'] = '3'
# Réindexer le DataFrame après la suppression
#tab_players_2000 = tab_players_2000.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_2000.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2000.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_2000])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_2000  

#parse_players_2000()
# Out:
#     Primary_Key  Rank                   Nom               Club  \
# 0           297     1             Luis Figo       FC Barcelone
# 1           298     2       Zinedine Zidane        Juventus FC
# 2           299     3     Andriy Shevchenko           Milan AC
# 3           300     4         Thierry Henry            Arsenal
# 4           301     5      Alessandro Nesta              Lazio
# 5           302     6               Rivaldo       FC Barcelone
# 6           303     7     Gabriel Batistuta               Roma
# 7           304     8       Gaizka Mendieta           Valencia
# 8           305     9                  Raul        Real Madrid
# 9           306    10         Paolo Maldini           Milan AC
# 10          307    10         David Beckham  Manchester United
# 11          308    12        Zlatko Zahovic         Olympiacos
# 12          309    12        Fabien Barthez  Manchester United
# 13          310    14       Francesco Toldo         Fiorentina
# ...

# %%
#def parse_players_2001():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/2001_Ballon_d%27Or")
tab_players_2001 = scraper[0]
#tab_players_2001 = tab_players_2001.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_2001 = tab_players_2001.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2001 = tab_players_2001.rename(columns = {'Name': 'Nom'})
tab_players_2001 = tab_players_2001.rename(columns = {'Club(s)': 'Club'})
tab_players_2001 = tab_players_2001.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_2001['pourcentage_vote']= tab_players_2001['pourcentage_vote'].str.replace('%','')
#tab_players_2001['pourcentage_vote']= tab_players_2001['pourcentage_vote'].str.replace('\"','')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('Atlético','Atletico')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Brésil','Bresil') 
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Germany','Allemagne')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Égypte','Egypte')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Sweden','Suede')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Italy','Italie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Croatia','Croatie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Norway','Norvege')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Switzerland','Suisse')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Belgium','Belgique')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Austria','Australie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Russia','Russie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Greece','Grece')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Wales','Pays de Galles')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Denmark','Danemark')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('England','Angleterre')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Spain','Espagne')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Argentina','Argentine')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Slovenia','Slovenie')
tab_players_2001['Selection']= tab_players_2001['Selection'].str.replace('Brazil','Bresil')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('Milan','Milan AC')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('Internazionale','Inter Milan')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('Juventus','Juventus FC')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('Liège','Liege')
tab_players_2001['Club']= tab_players_2001['Club'].str.replace('La Coruña','La Corogne')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Élber','Elber')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Poborský','Poborsky')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Prosinečki','Prosinecki')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Stojković','Stojkovic')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Jürgen','Jurgen')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Savićević','Savicevic')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Luís','Luis')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Şükür','Sukur')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Zahovič','Zahovic')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Mário','Mario')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Šuker','Suker')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('López','Lopez')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Nedvěd','Nedved')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Raúl','Raul')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Sebastián Verón','Sebastian Veron')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Matthaus','Matthaus')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Siniša','Sinisa')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Hernán','Hernan')
tab_players_2001['Nom']= tab_players_2001['Nom'].str.replace('Mihajlović','Mihajlovic')
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_2001.at[15,'Club'] = 'Lazio'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_2001.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2001['Type']='1' #(add 1 for UEFA by default)
tab_players_2001['Year']='2001'

tab_players_2001.insert(loc=4, column='Poste', value='Attaquant')
tab_players_2001.insert(loc=0, column='Primary_Key', value=range(327,len(tab_players_2001) + 327))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_2001 = tab_players_2001.drop(index=len(tab_players_2001))

# Réindexer le DataFrame après la suppression
#tab_players_2001 = tab_players_2001.reset_index(drop=True)
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2001['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2001['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2001.loc[condition_CAF, 'Type'] = '2'
tab_players_2001.loc[condition_CONMEBOL, 'Type'] = '3'

    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_2001.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2001.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_2001])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_2001  

#parse_players_2001()
# Out:
#     Primary_Key  Rank                      Nom                Club  \
# 0           327     1             Michael Owen           Liverpool
# 1           328     2                     Raul         Real Madrid
# 2           329     3              Oliver Kahn       Bayern Munich
# 3           330     4            David Beckham   Manchester United
# 4           331     5          Francesco Totti           A.S. Roma
# 5           332     6                Luis Figo         Real Madrid
# 6           333     7                  Rivaldo        FC Barcelone
# 7           334     8        Andriy Shevchenko            Milan AC
# 8           335     9            Thierry Henry             Arsenal
# 9           336     9          Zinedine Zidane         Real Madrid
# 10          337    11         Bixente Lizarazu       Bayern Munich
# 11          338    12          David Trezeguet         Juventus FC
# 12          339    13         Stefan Effenberg       Bayern Munich
# ...

# %%
#def parse_players_2002():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/2002_Ballon_d%27Or")
tab_players_2002 = scraper[0]
#tab_players_2002 = tab_players_2002.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_2002 = tab_players_2002.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_2002 = tab_players_2002.rename(columns = {'Player': 'Nom'})
tab_players_2002 = tab_players_2002.rename(columns = {'Club(s)': 'Club'})
tab_players_2002 = tab_players_2002.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_2002['pourcentage_vote']= tab_players_2002['pourcentage_vote'].str.replace('%','')
#tab_players_2002['pourcentage_vote']= tab_players_2002['pourcentage_vote'].str.replace('\"','')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('Atlético','Atletico')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Brésil','Bresil') 
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Germany','Allemagne')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Égypte','Egypte')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Sweden','Suede')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Italy','Italie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Croatia','Croatie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Norway','Norvege')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Switzerland','Suisse')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Belgium','Belgique')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Austria','Australie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Russia','Russie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Greece','Grece')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Wales','Pays de Galles')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Denmark','Danemark')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('England','Angleterre')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Spain','Espagne')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Argentina','Argentine')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Slovenia','Slovenie')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Brazil','Bresil')
tab_players_2002['Selection']= tab_players_2002['Selection'].str.replace('Turkey','Turquie')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('Milan','Milan AC')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('Internazionale','Inter Milan')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('Juventus','Juventus FC')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('Liège','Liege')
tab_players_2002['Club']= tab_players_2002['Club'].str.replace('La Coruña','La Corogne')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace(' Baştürk',' Basturk')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Şaş','Sas')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Lúcio','Lucio')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Stojković','Stojkovic')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Jürgen','Jurgen')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Savićević','Savicevic')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Luís','Luis')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Şükür','Sukur')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Zahovič','Zahovic')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Mário','Mario')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Šuker','Suker')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('López','Lopez')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Nedvěd','Nedved')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Raúl','Raul')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Sebastián Verón','Sebastian Veron')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Matthaus','Matthaus')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Siniša','Sinisa')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Hernán','Hernan')
tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('Mihajlović','Mihajlovic')
#tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('[notes 1]','')
#tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('[notes 2]','')
#tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('[notes 3]','')
#tab_players_2002['Nom']= tab_players_2002['Nom'].str.replace('[notes 4]','')
# modifier les valeurs en anglais dans les colonnes suivante
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_2002.at[0,'Nom'] = 'Ronaldo'
tab_players_2002.at[2,'Nom'] = 'Oliver Kahn'
tab_players_2002.at[4,'Nom'] = 'Michael Ballack'
tab_players_2002.at[7,'Nom'] = 'Rivaldo'
tab_players_2002.at[0,'Club'] = 'Inter Milan'
tab_players_2002.at[4,'Club'] = 'Bayer Leverkusen' 
tab_players_2002.at[7,'Club'] = 'FC Barcelone' 
tab_players_2002.at[22,'Club'] = 'Leeds United'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_2002.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2002['Type']='1' #(add 1 for UEFA by default)
tab_players_2002['Year']='2002'

tab_players_2002.insert(loc=4, column='Poste', value='Attaquant')
tab_players_2002.insert(loc=0, column='Primary_Key', value=range(377,len(tab_players_2002) + 377))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_2002 = tab_players_2002.drop(index=len(tab_players_2002))
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2002['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2002['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2002.loc[condition_CAF, 'Type'] = '2'
tab_players_2002.loc[condition_CONMEBOL, 'Type'] = '3'
# Réindexer le DataFrame après la suppression
#tab_players_2002 = tab_players_2002.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_2002.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2002.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_2002])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_2002  

#parse_players_2002()
# Out:
#     Primary_Key  Rank                   Nom   Selection                  Club  \
# 0           377     1               Ronaldo      Bresil           Inter Milan
# 1           378     2        Roberto Carlos      Bresil           Real Madrid
# 2           379     3           Oliver Kahn   Allemagne         Bayern Munich
# 3           380     4       Zinedine Zidane      France           Real Madrid
# 4           381     5       Michael Ballack   Allemagne      Bayer Leverkusen
# 5           382     6         Thierry Henry      France               Arsenal
# 6           383     7                  Raul     Espagne           Real Madrid
# 7           384     8               Rivaldo      Bresil          FC Barcelone
# 8           385     9      Yıldıray Basturk     Turquie      Bayer Leverkusen
# 9           386    10  Alessandro Del Piero      Italie           Juventus FC
# 10          387    11             Hasan Sas     Turquie           Galatasaray
# ...

# %%
#def parse_players_2007():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/2007_Ballon_d%27Or")
print("Ballon 2007 scrapper")
tab_players_2007 = scraper[2]

tab_players_2007 = tab_players_2007.rename(columns = {'Player': 'Nom'})
tab_players_2007 = tab_players_2007.rename(columns = {'Club(s)': 'Club'})
tab_players_2007 = tab_players_2007.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_2007['pourcentage_vote']= tab_players_2007['pourcentage_vote'].str.replace('%','')
#tab_players_2007['pourcentage_vote']= tab_players_2007['pourcentage_vote'].str.replace('\"','')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('Atlético','Atletico')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Brésil','Bresil') 
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Germany','Allemagne')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Égypte','Egypte')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Sweden','Suede')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Italy','Italie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Ivory Coast','Cote d\'ivoire')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Croatia','Croatie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Norway','Norvege')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Switzerland','Suisse')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Belgium','Belgique')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Austria','Australie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Russia','Russie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Greece','Grece')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Wales','Pays de Galles')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Denmark','Danemark')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('England','Angleterre')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Spain','Espagne')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Argentina','Argentine')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Slovenia','Slovenie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Brazil','Bresil')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Turkey','Turquie')
tab_players_2007['Selection']= tab_players_2007['Selection'].str.replace('Cameroon','Cameroun')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('Milan','Milan AC')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('Internazionale','Inter Milan')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('Juventus','Juventus FC')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('São Paulo','Sao Paulo')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('La Coruña','La Corogne')
tab_players_2007['Club']= tab_players_2007['Club'].str.replace('Sevilla','Seville')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Román','Roman')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Kaká','Kaka')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Lúcio','Lucio')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Fàbregas','Fabregas')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Frédéric Kanouté','Frederic Kanoute')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Luís','Luis')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Şükür','Sukur')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Zahovič','Zahovic')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Ribéry','Ribery')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Čech','Cech')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('López','Lopez')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Nedvěd','Nedved')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Raúl','Raul')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Rogério','Rogerio')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Matthaus','Matthaus')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Siniša','Sinisa')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Hernán','Hernan')
tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('Mihajlović','Mihajlovic')
#tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('[notes 1]','')
#tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('[notes 2]','')
#tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('[notes 3]','')
#tab_players_2007['Nom']= tab_players_2007['Nom'].str.replace('[notes 4]','')
# modifier les valeurs en anglais dans les colonnes suivante
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
tab_players_2007.at[13,'Club'] = 'Villarreal'
tab_players_2007.at[16,'Club'] = 'Marseille' 
tab_players_2007.at[21,'Club'] = 'Arsenal' 
tab_players_2007.at[33,'Club'] = 'West Ham United'
tab_players_2007.at[35,'Club'] = 'Lyon'
tab_players_2007.at[41,'Club'] = 'Lyon'
tab_players_2007.at[48,'Club'] = 'Atletico Madrid' 
tab_players_2007.at[36,'Club'] = 'Real Madrid'
tab_players_2007.at[40,'Club'] = 'Werder Breme'
# Add columns for conferation , type, poste,Primary_key, Year

tab_players_2007.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2007['Type']='1' #(add 1 for UEFA by default)
tab_players_2007['Year']='2007'

tab_players_2007.insert(loc=4, column='Poste', value='Attaquant')
tab_players_2007.insert(loc=0, column='Primary_Key', value=range(403,len(tab_players_2007) + 403))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_2007 = tab_players_2007.drop(index=len(tab_players_2007))
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2007['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2007['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2007.loc[condition_CAF, 'Type'] = '2'
tab_players_2007.loc[condition_CONMEBOL, 'Type'] = '3'
# Réindexer le DataFrame après la suppression
#tab_players_2007 = tab_players_2007.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_2007.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2007.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_2007])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_2007
# Out:
# Ballon 2007 scrapper
#     Primary_Key  Rank                  Nom           Selection  \
# 0           403     1                 Kaka              Bresil
# 1           404     2    Cristiano Ronaldo            Portugal
# 2           405     3         Lionel Messi           Argentine
# 3           406     4        Didier Drogba       Cote d'ivoire
# 4           407     5         Andrea Pirlo              Italie
# 5           408     6  Ruud van Nistelrooy            Pays-Bas
# 6           409     7   Zlatan Ibrahimovic               Suede
# 7           410     8        Cesc Fabregas             Espagne
# 8           411     9              Robinho              Bresil
# 9           412    10      Francesco Totti              Italie
# 10          413    11     Frederic Kanoute                Mali
# 11          414    12           Ronaldinho              Bresil
# 12          415    13       Steven Gerrard          Angleterre
# ...

# %%
#def parse_players_2008():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/2008_Ballon_d%27Or")

tab_players_2008 = scraper[2]

tab_players_2008 = tab_players_2008.rename(columns = {'Player': 'Nom'})
tab_players_2008 = tab_players_2008.rename(columns = {'Club(s)': 'Club'})
tab_players_2008 = tab_players_2008.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_2008['pourcentage_vote']= tab_players_2008['pourcentage_vote'].str.replace('%','')
#tab_players_2008['pourcentage_vote']= tab_players_2008['pourcentage_vote'].str.replace('\"','')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('Atlético','Atletico')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Brésil','Bresil') 
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Germany','Allemagne')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Égypte','Egypte')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Sweden','Suede')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Italy','Italie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Ivory Coast','Cote d\'ivoire')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Croatia','Croatie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Norway','Norvege')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Switzerland','Suisse')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Belgium','Belgique')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Austria','Australie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Russia','Russie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Greece','Grece')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Wales','Pays de Galles')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Denmark','Danemark')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('England','Angleterre')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Spain','Espagne')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Argentina','Argentine')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Slovenia','Slovenie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Brazil','Bresil')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Turkey','Turquie')
tab_players_2008['Selection']= tab_players_2008['Selection'].str.replace('Cameroon','Cameroun')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('Milan','Milan AC')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('Internazionale','Inter Milan')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('Juventus','Juventus FC')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('São Paulo','Sao Paulo')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('La Coruña','La Corogne')
tab_players_2008['Club']= tab_players_2008['Club'].str.replace('CSKA Moscow','CSKA Moscou')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Román','Roman')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Kaká','Kaka')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Lúcio','Lucio')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Fàbregas','Fabregas')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Frédéric Kanouté','Frederic Kanoute')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Luís','Luis')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Şükür','Sukur')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Zahovič','Zahovic')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Ribéry','Ribery')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Čech','Cech')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('López','Lopez')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Nedvěd','Nedved')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Raúl','Raul')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Rogério','Rogerio')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Matthaus','Matthaus')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Siniša','Sinisa')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Vidić','Vidic')
tab_players_2008['Nom']= tab_players_2008['Nom'].str.replace('Mihajlović','Mihajlovic')


# Modifier une cellule spécifique
#tab_players_2008.at[13,'Club'] = 'Villarreal'


# Add columns for conferation , type, poste,Primary_key, Year

tab_players_2008.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2008['Type']='1' #(add 1 for UEFA by default)
tab_players_2008['Year']='2008'

tab_players_2008.insert(loc=4, column='Poste', value='Attaquant')
tab_players_2008.insert(loc=0, column='Primary_Key', value=range(453,len(tab_players_2008) + 453))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_2008 = tab_players_2008.drop(index=len(tab_players_2008))
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2008['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2008['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2008.loc[condition_CAF, 'Type'] = '2'
tab_players_2008.loc[condition_CONMEBOL, 'Type'] = '3'
# Réindexer le DataFrame après la suppression
#tab_players_2008 = tab_players_2008.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_2008.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2008.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_2008])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_2008
# Out:
# Ballon 2008 scrapper
#     Primary_Key  Rank                   Nom      Selection  \
# 0           453     1     Cristiano Ronaldo       Portugal
# 1           454     2          Lionel Messi      Argentine
# 2           455     3       Fernando Torres        Espagne
# 3           456     4         Iker Casillas        Espagne
# 4           457     5                  Xavi        Espagne
# 5           458     6       Andrey Arshavin         Russie
# 6           459     7           David Villa        Espagne
# 7           460     8    Zlatan Ibrahimovic          Suede
# 8           461     9                  Kaka         Bresil
# 9           462    10        Steven Gerrard     Angleterre
# 10          463    11          Marcos Senna        Espagne
# 11          464    12     Emmanuel Adebayor           Togo
# 12          465    13          Wayne Rooney     Angleterre
# 13          466    14         Sergio Agüero      Argentine
# ...

# %%
#def parse_players_2009():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/2009_Ballon_d%27Or")

tab_players_2009 = scraper[2]

tab_players_2009 = tab_players_2009.rename(columns = {'Player': 'Nom'})
tab_players_2009 = tab_players_2009.rename(columns = {'Club(s)': 'Club'})
tab_players_2009 = tab_players_2009.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_2009['pourcentage_vote']= tab_players_2009['pourcentage_vote'].str.replace('%','')
#tab_players_2009['pourcentage_vote']= tab_players_2009['pourcentage_vote'].str.replace('\"','')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('Atlético','Atletico')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Brésil','Bresil') 
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Germany','Allemagne')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Égypte','Egypte')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Sweden','Suede')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Italy','Italie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Ivory Coast','Cote d\'ivoire')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Czech Republic','Republique-Tcheque')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Croatia','Croatie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Norway','Norvege')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Switzerland','Suisse')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Belgium','Belgique')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Austria','Australie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Russia','Russie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Greece','Grece')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Wales','Pays de Galles')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Denmark','Danemark')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('England','Angleterre')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Spain','Espagne')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Argentina','Argentine')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Slovenia','Slovenie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Brazil','Bresil')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Turkey','Turquie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Serbia','Serbie')
tab_players_2009['Selection']= tab_players_2009['Selection'].str.replace('Cameroon','Cameroun')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('Milan','Milan AC')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('Internazionale','Inter Milan')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('Juventus','Juventus FC')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('São Paulo','Sao Paulo')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('La Coruña','La Corogne')
tab_players_2009['Club']= tab_players_2009['Club'].str.replace('CSKA Moscow','CSKA Moscou')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Román','Roman')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Kaká','Kaka')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Lúcio','Lucio')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Ibrahimović','Ibrahimovic')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Fàbregas','Fabregas')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Frédéric Kanouté','Frederic Kanoute')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Luís','Luis')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Şükür','Sukur')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Zahovič','Zahovic')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Ribéry','Ribery')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Čech','Cech')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('López','Lopez')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Nedvěd','Nedved')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Raúl','Raul')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Rogério','Rogerio')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Matthaus','Matthaus')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Siniša','Sinisa')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Vidić','Vidic')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Mihajlović','Mihajlovic')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Džeko','Dzeko')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Forlán','Forlan')
tab_players_2009['Nom']= tab_players_2009['Nom'].str.replace('Júlio César','Julio Cesar')

# Modifier une cellule spécifique
tab_players_2009.at[1,'Club'] = 'Manchester United'
tab_players_2009.at[4,'Club'] = 'FC Barcelone' 
tab_players_2009.at[5,'Club'] = 'Milan AC'
tab_players_2009.at[6,'Club'] = 'Inter Milan'
tab_players_2009.at[24,'Club'] = 'Werder Breme'
tab_players_2009.at[29,'Club'] = 'Lyon'
# Add columns for conferation , type, poste,Primary_key, Year

tab_players_2009.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_2009['Type']='1' #(add 1 for UEFA by default)
tab_players_2009['Year']='2009'

tab_players_2009.insert(loc=4, column='Poste', value='Attaquant')
tab_players_2009.insert(loc=0, column='Primary_Key', value=range(483,len(tab_players_2009) + 483))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_2009 = tab_players_2009.drop(index=len(tab_players_2009))
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili','Uruguay']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria','Gabon']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_2009['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_2009['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_2009.loc[condition_CAF, 'Type'] = '2'
tab_players_2009.loc[condition_CONMEBOL, 'Type'] = '3'
# Réindexer le DataFrame après la suppression
#tab_players_2009 = tab_players_2009.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_2009.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_2009.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_2009])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_2009
# Out:
#     Primary_Key  Rank                 Nom               Selection  \
# 0           483     1        Lionel Messi               Argentine
# 1           484     2   Cristiano Ronaldo                Portugal
# 2           485     3                Xavi                 Espagne
# 3           486     4      Andrés Iniesta                 Espagne
# 4           487     5        Samuel Eto'o                Cameroun
# 5           488     6                Kaka                  Bresil
# 6           489     7  Zlatan Ibrahimovic                   Suede
# 7           490     8        Wayne Rooney              Angleterre
# 8           491     9       Didier Drogba           Cote d'ivoire
# 9           492    10      Steven Gerrard              Angleterre
# 10          493    11     Fernando Torres                 Espagne
# 11          494    12       Cesc Fabregas                 Espagne
# 12          495    13          Edin Dzeko  Bosnia and Herzegovina
# ...

# %%
import numpy as np
import pandas as pd
#def parse_players_1989():
 
scraper = pd.read_html("https://en.wikipedia.org/wiki/1989_Ballon_d%27Or")
tab_players_1989 = scraper[0]
#tab_players_1989 = tab_players_1989.rename(columns = {'%': 'pourcentage_vote'})
#tab_players_1989 = tab_players_1989.rename(columns = {'Sélection nationale': 'Selection'})
tab_players_1989 = tab_players_1989.rename(columns = {'Name': 'Nom'})
tab_players_1989 = tab_players_1989.rename(columns = {'Club(s)': 'Club'})
tab_players_1989 = tab_players_1989.rename(columns = {'Nationality': 'Selection'})
    
# remplace les symboles pourcentages dans la derniere colonne
#tab_players_1989['pourcentage_vote']= tab_players_1989['pourcentage_vote'].str.replace('%','')
#tab_players_1989['pourcentage_vote']= tab_players_1989['pourcentage_vote'].str.replace('\"','')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Atlético','Atletico')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Brésil','Bresil') 
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Germany','Allemagne')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('West Allemagne','Allemagne')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Égypte','Egypte')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Netherlands','Pays-Bas')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Sweden','Suede')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Italy','Italie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Bosnie-Herzégovine','Bosnie-Herzegovine')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Croatia','Croatie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Norway','Norvege')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Bulgaria','Bulgarie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Switzerland','Suisse')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Belgium','Belgique')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Romania','Roumanie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Austria','Australie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Russia','Russie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Greece','Grece')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Wales','Pays de Galles')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Denmark','Danemark')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('England','Angleterre')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Republic of Ireland','Irelande')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Spain','Espagne')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('FR Yugoslavia','Yougoslavie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Argentina','Argentine')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Slovenia','Slovenie')
tab_players_1989['Selection']= tab_players_1989['Selection'].str.replace('Brazil','Bresil')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Milan','Milan AC')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Internazionale','Inter Milan')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Juventus','Juventus FC')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Barcelona','FC Barcelone')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('1. FC Köln','Cologne')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Steaua București','Steauat Bucarest')
tab_players_1989['Club']= tab_players_1989['Club'].str.replace('Kyiv','Kiev')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('FrakRijkaard','Frank Rijkaard')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Matthäus','Matthaus')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Lúcio','Lucio')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Stojković','Stojkovic')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Mijatović','Mijatovic') 
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Jürgen','Jurgen')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Savićević','Savicevic')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Luís','Luis')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('DragaSjkvic','Draga Stojkovic')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Zahovič','Zahovic')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Mário','Mario')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Šuker','Suker')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('López','Lopez')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Nedvěd','Nedved')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Häßler','Hassler')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Sebastián Verón','Sebastian Veron')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Matthaus','Matthaus')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Hysén','Hysen')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Möller','Moller')
tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('Mihajlović','Mihajlovic')
#tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('[notes 1]','')
#tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('[notes 2]','')
#tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('[notes 3]','')
#tab_players_1989['Nom']= tab_players_1989['Nom'].str.replace('[notes 4]','')

# modifier les valeurs en anglais dans les colonnes suivante
# modifier les valeurs en anglais dans les colonnes suivante

# Modifier une cellule spécifique
#tab_players_1989.at[1,'Club'] = 'Liverpool FC'

# Add columns for conferation , type, poste,Primary_key, Year

tab_players_1989.insert(loc=5, column='Confederation', value='UEFA')#( add UEFA by default)
tab_players_1989['Type']='1' #(add 1 for UEFA by default)
tab_players_1989['Year']='1989'

tab_players_1989.insert(loc=4, column='Poste', value='Attaquant')
tab_players_1989.insert(loc=0, column='Primary_Key', value=range(377,len(tab_players_1989) + 377))
# Supprimer une ligne spécifique en utilisant drop()
#tab_players_1989 = tab_players_1989.drop(index=len(tab_players_1989))

#tab_players_1989.loc[tab_players_1989['Selection'] == 'West Allemagne', 'Type'] = '2'
# Tableau de valeurs à comparer
valeurs_CONMEBOL = ['Bresil', 'Argentine', 'Colombie','Chili']
valeurs_CAF =  ['Senegal', 'Cameroun', 'Algerie','Nigeria']
# Vérifier si la valeur de la colonne 'Selection' se trouve dans le tableau de valeurs
condition_CONMEBOL = tab_players_1989['Selection'].isin(valeurs_CONMEBOL)
condition_CAF = tab_players_1989['Selection'].isin(valeurs_CAF)

# Modifier la valeur de la colonne 'Type' en fonction de la condition
tab_players_1989.loc[condition_CAF, 'Type'] = '2'
tab_players_1989.loc[condition_CONMEBOL, 'Type'] = '3'

# Réindexer le DataFrame après la suppression
#tab_players_1989 = tab_players_1989.reset_index(drop=True)
    
    ## Supprimer une colonne en utilisant del
    #del df['Col1']
 
    # write dataframe ina csv file
tab_players_1989.to_csv(r'C:\Users\messj\Ballon_d_Or\players_90_99\tab_players_1989.csv', sep = ',',header=True, index=False)

players_90_99 = pd.concat([players_90_99,tab_players_1989])
players_90_99.to_csv('all_players_1990_99.csv', sep=',', header=True, index=False)
tab_players_1989  

#parse_players_1989()
# Out:
# C:\Users\messj\AppData\Local\Temp\ipykernel_12268\138144658.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   tab_players_1989['Club']= tab_players_1989['Club'].str.replace('1. FC Köln','Cologne')
#     Primary_Key  Rank                     Nom               Club  \
# 0           377     1        Marco van Basten        AC Milan AC
# 1           378     2           Franco Baresi           Milan AC
# 2           379     3          Frank Rijkaard           Milan AC
# 3           380     4         Lothar Matthaus        Inter Milan
# 4           381     5           Peter Shilton       Derby County
# 5           382     6        Dragan Stojkovic  Red Star Belgrade
# 6           383     7             Ruud Gullit           Milan AC
# 7           384     8           Gheorghe Hagi   Steauat Bucarest
# 8           385     8        Jurgen Klinsmann        Inter Milan
# 9           386    10       Jean-Pierre Papin          Marseille
# ...
